# %% [markdown]
# # Notebook on segmentation of cluster of cells
#
# Author : Aaron MAMANN

# %% [markdown]
# ## Libraries

# %%
import os
import PIL
from PIL import Image, ImageOps, ImageEnhance, __version__ as PILLOW_VERSION
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import re
import random
from natsort import natsorted
import glob
from skimage import img_as_ubyte
import skimage 
from skimage.transform import rescale, resize, downscale_local_mean
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision 
from torchvision import transforms
from torchmetrics import Dice
import shutil
import cv2
import csv
from skimage.measure import label, regionprops, regionprops_table
import tifffile
import tifffile as tiff
from pathlib import Path
from tqdm.notebook import tqdm

# %% [markdown]
# ## Main Function : Galbor Filter with specific Preprocessing and PostProcessing Functions

# %%
def create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter,fill_cells,experiment_name='ECB',save_predicted_mask=True,compute_score=True,ratio_first_thresh=300/(1920*1440),ratio_small_object_thresh=4000/(1920*1440),ratio_thresh_big_objects=30000/(1920*1440),ratio_canal_diameter=110/1440, fill_big_objects=7 ):

    experiment_types_dir = [  "".join([file_dir,'/',f]) for f in natsorted(os.listdir(file_dir)) if experiment_name in f]  
    
    if compute_score : 
        score_experiment=dict()
    
    for type_dir in experiment_types_dir:
        l=0
        conditions_experiment= [  f for f in natsorted(os.listdir(type_dir) ) if experiment_name in f]    
        for condition in conditions_experiment : 
            sequences=[ "".join([type_dir,'/',condition,'/',image_files_name,'/',f]) for f in  natsorted(os.listdir( "".join([type_dir,'/',condition,'/',image_files_name]) )) if experiment_name in f]
            if save_predicted_mask :         
                Path("".join([type_dir,'/',condition,'/masks_predicted/'])).mkdir(parents=True, exist_ok=True)
                                              
            for sequence in sequences:
          
                images_in_tiff = tifffile.imread(sequence)              
                if np.ndim(images_in_tiff)==2 :
                    images_in_tiff = np.expand_dims(images_in_tiff, axis=0)
                nb_images_in_tiff = len(images_in_tiff)
                predicted_mask=list()
            
                if compute_score : 
                    masks_in_tiff = tifffile.imread( "".join([type_dir,'/',condition,'/',mask_files_name,'/',os.path.basename(sequence).replace(".tif", "_mask.tif") ]) )
                    if np.ndim(masks_in_tiff)==2 :
                        masks_in_tiff = np.expand_dims(masks_in_tiff, axis=0)
                    score_sequence=0
            
                j=0         
                for index_one_image in range(nb_images_in_tiff): 
                    nb_pixels=images_in_tiff[index_one_image].shape[0]*images_in_tiff[index_one_image].shape[1]
                    nb_vertical_pixels=images_in_tiff[index_one_image].shape[0]
                    thresh_small_objects=ratio_small_object_thresh*nb_pixels
                    first_thresh=ratio_first_thresh*nb_pixels
                    im_original=skimage.morphology.remove_small_objects(scipy.ndimage.binary_fill_holes(skimage.morphology.binary_closing(skimage.morphology.remove_small_objects(scipy.ndimage.binary_fill_holes(skimage.filters.gabor(img_as_ubyte(skimage.exposure.rescale_intensity(images_in_tiff[index_one_image])),gabor_parameter)[1]),min_size=first_thresh, connectivity=1),footprint=np.ones((fill_cells,fill_cells)))),min_size=thresh_small_objects,connectivity=1)
                    thresh_big_objects=ratio_thresh_big_objects*nb_pixels 
                    im_original = img_as_ubyte(im_original)
                  
                    labeled_im = label(im_original)

                    canal_diameter=ratio_canal_diameter*nb_vertical_pixels 
                    props = regionprops(labeled_im)
                    for i in range(len(props)) :
                        if abs(props[i].bbox[2]-props[i].bbox[0])>canal_diameter :
                            im_original[props[i].bbox[0]:props[i].bbox[2]+1,props[i].bbox[1]:props[i].bbox[3]+1] = 0
        
                    im_original=img_as_ubyte(skimage.morphology.remove_small_objects(np.array(im_original,dtype=bool),min_size=thresh_small_objects,connectivity=1))
                    new_image=img_as_ubyte(np.pad(im_original, (50, 50),'constant',constant_values=255))  
                    im_big_objects=img_as_ubyte( skimage.morphology.remove_small_objects(np.pad(skimage.morphology.binary_closing(im_original,footprint=np.ones((fill_big_objects, fill_big_objects)) ), (50, 50), 'constant', constant_values=255) ,min_size=thresh_big_objects )  ) 
                    new_image = new_image - im_big_objects
                    new_image[(new_image>0) & (new_image<127.5)]=0
                    new_image[(new_image>=127.5) & (new_image<255)]=255
                    shape_im = new_image.shape
                    new_image=new_image[50:shape_im[0]-50,50:shape_im[1]-50]   
                    if compute_score : 
                        true_mask = img_as_ubyte(masks_in_tiff[index_one_image])
                        #accuracy = Accuracy(mdmc_reduce='global',num_classes=2,average='none')                        
                        dice = Dice(average=None,num_classes=2)
                        score_sequence = score_sequence + dice(torch.where(torch.from_numpy(new_image)> 0, True, False), torch.where(torch.from_numpy(true_mask)> 0, True, False)).numpy()[1]    
                                                                         
                    if j==0:
                        predicted_mask=[np.array(new_image, dtype=np.uint16)]                 
                    else:
                        predicted_mask=np.append(predicted_mask,[np.array(new_image, dtype=np.uint16)],axis=0)
                    j=j+1
                 
                if save_predicted_mask :       
                    tiff.imsave("".join([type_dir,'/',condition,'/masks_predicted/',os.path.basename(sequence)]),predicted_mask)
            
                if compute_score : 
                    score_sequence = score_sequence/nb_images_in_tiff
                    score_experiment[sequence] = score_sequence
                l=l+1
                if compute_score : 
                    print("".join([os.path.basename(type_dir),',',condition,': Tiff ',str(os.path.basename(sequence).replace(".tif", " ")),'segmented (Tiff n°', str(l) ,'), gabor param ',str(gabor_parameter), ', fill param ', str(fill_cells), ', score: ', str(round(score_sequence, 4)) ]))        
    if compute_score : 
        return score_experiment

# %%
# Clémence you have to simulate that, the following part is the training and the test which allowed to find the value of gabor parameter (equal to 0.78)
# and the value of the fill cell parameter (equal to 5) 

file_dir='/Users/clemence/Documents_Clémence/Analysis/Tracking algorithm/Tracking-seg_Aaron-Gus_CNV/To run' # change this into your own path
image_files_name = 'Source images'
mask_files_name = 'Masks'

create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=0.79,fill_cells=9,save_predicted_mask=True,compute_score=False)
# Out:
# /var/folders/t9/fgr9lrds0dvgw45q0n6x3xfm0000gn/T/ipykernel_10320/2999694229.py:69: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tiff.imsave("".join([type_dir,'/',condition,'/masks_predicted/',os.path.basename(sequence)]),predicted_mask)

# %% [markdown]
# # Tune jointly Fill Big Objects and Canal Diameter

# %%
hyperparameter_candidates = [[5,107],[5,108],[5,109],[5,110],[7,107],[7,108],[7,109],[7,110],[9,107],[9,108],[9,109],[9,110],[11,107],[11,108],[11,109],[11,110]]

dice_score_pixels_nb = list(map(lambda x: [x[0],x[1],np.array(list(create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=0.79,fill_cells=8,fill_big_objects=x[0],ratio_canal_diameter=x[1]/1440,save_predicted_mask=False).values())).mean() ] , hyperparameter_candidates))
dice_score_pixels_nb=pd.DataFrame(dice_score_pixels_nb)
dice_score_pixels_nb.columns = ['fill_big_objects', 'canal_diameter', 'Min_pixels', 'Dice scores']
dice_score_pixels_nb

# %% [markdown]
# # Allocate randomly .tif file into the training set and the test set

# %%
# This function moves some tif files into a file used for training (tuning the gabor parameter, 
# fill parameter, minimum number of pixels parameter) and into another file used for testing

def create_training_and_test_files_for_each_experiment(file_dir,image_files_name,mask_files_name,experiment_name='CNV'):
                 
    l=0
    sequences=[ "".join([file_dir,'/',image_files_name,'/',f]) for f in  natsorted(os.listdir( "".join([file_dir,'/',image_files_name]) )) if experiment_name in f]
    training_set=random.sample(sequences, k=int(len(sequences)*0.7))
    test_set=list(set(sequences) - set(training_set))
    
    Path("".join([file_dir,'/training/CNV_mutiples/Source images/'])).mkdir(parents=True, exist_ok=True)
    Path("".join([file_dir,'/training/CNV_mutiples/Masks/'])).mkdir(parents=True, exist_ok=True)
    
    for sequence in training_set:
        os.replace(sequence, "".join([file_dir,'/training/CNV_mutiples/Source images/',os.path.basename(sequence)]))
        os.replace( "".join([file_dir,'/',mask_files_name,'/',os.path.basename(sequence).replace(".tif", "_mask.tif") ]), "".join([file_dir,'/training/CNV_mutiples/Masks/',os.path.basename(sequence).replace(".tif", "_mask.tif") ]))
        
    Path("".join([file_dir,'/test/CNV_mutiples/Source images/'])).mkdir(parents=True, exist_ok=True)
    Path("".join([file_dir,'/test/CNV_mutiples/Masks/'])).mkdir(parents=True, exist_ok=True)
    
    for sequence in test_set:
        os.replace(sequence, "".join([file_dir,'/test/CNV_mutiples/Source images/',os.path.basename(sequence)]))
        os.replace( "".join([file_dir,'/',mask_files_name,'/',os.path.basename(sequence).replace(".tif", "_mask.tif") ]), "".join([file_dir,'/test/CNV_mutiples/Masks/',os.path.basename(sequence).replace(".tif", "_mask.tif") ]))
     
    shutil.rmtree("".join([file_dir,'/',image_files_name]) ) 
    shutil.rmtree("".join([file_dir,'/',mask_files_name]) )

# %%
# We execute this function to create a training file (with images and masks) and a test file (with images and masks)

file_dir='/Users/aaronmamann/Desktop/Cleaned_Datasets_Clemence/Validation' # change this into your own path
create_training_and_test_files_for_each_experiment(file_dir=file_dir,image_files_name='Source images',mask_files_name='Masks',experiment_name='CNV')

# %% [markdown]
# ## Tuning hyperparameters (gabor, fill, number pixels for mask) on training set

# %%
file_dir = '/Users/aaronmamann/Desktop/Cleaned_Datasets_Clemence/Data_Val/Training' # change this into your own path
image_files_name = 'Source images'
mask_files_name = 'Masks'
# We are going to tune jointly the gabor parameter and the fill parameter on the training set

hyperparameter_candidates = [[0.76,5],[0.77,5],[0.78,5],[0.79,5],[0.76,10],[0.77,10],[0.78,10],[0.79,10],[0.76,15],[0.77,15],[0.78,15],[0.79,15],[0.76,20],[0.77,20],[0.78,20],[0.79,20] ]
dice_score_hyperparameters = list(map(lambda x: [x[0],x[1],np.array(list(create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=x[0],fill_cells=x[1],save_predicted_mask=False).values())).mean() ] , hyperparameter_candidates))
df_dice_scores=pd.DataFrame(dice_score_hyperparameters)
df_dice_scores.columns = ['gabor_param', 'fill_param', 'Min_pixels', 'Dice scores']
df_dice_scores
# Out:
# CNV_multiples: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.76, fill param 5, score: 0.884
# CNV_multiples: Tiff CNV006_20210430_791_t8 segmented (Tiff n°2), gabor param 0.76, fill param 5, score: 0.8557
# CNV_multiples: Tiff CNV006_20210430_793_t8 segmented (Tiff n°3), gabor param 0.76, fill param 5, score: 0.4859
# CNV_multiples: Tiff CNV010_20210606_065_t1 segmented (Tiff n°4), gabor param 0.76, fill param 5, score: 0.8956
# CNV_multiples: Tiff CNV010_20210606_065_t25 segmented (Tiff n°5), gabor param 0.76, fill param 5, score: 0.7747
# CNV_multiples: Tiff CNV010_20210606_066_t1 segmented (Tiff n°6), gabor param 0.76, fill param 5, score: 0.8388
# CNV_multiples: Tiff CNV010_20210606_066_t24 segmented (Tiff n°7), gabor param 0.76, fill param 5, score: 0.9015
# CNV_multiples: Tiff CNV010_20210606_067_t1 segmented (Tiff n°8), gabor param 0.76, fill param 5, score: 0.9202
# CNV_multiples: Tiff CNV010_20210606_095_t7 segmented (Tiff n°9), gabor param 0.76, fill param 5, score: 0.8925
# CNV_multiples: Tiff CNV010_20210606_095_t31 segmented (Tiff n°10), gabor param 0.76, fill param 5, score: 0.8969
# CNV_multiples: Tiff CNV010_20210606_095_t49 segmented (Tiff n°11), gabor param 0.76, fill param 5, score: 0.9134
# CNV_multiples: Tiff CNV010_20210606_111_t31 segmented (Tiff n°12), gabor param 0.76, fill param 5, score: 0.8517
# CNV_multiples: Tiff CNV010_20210606_111_t49 segmented (Tiff n°13), gabor param 0.76, fill param 5, score: 0.881
# CNV_multiples: Tiff CNV010_20210606_137_t7 segmented (Tiff n°14), gabor param 0.76, fill param 5, score: 0.8856
# CNV_multiples: Tiff CNV010_20210606_137_t31 segmented (Tiff n°15), gabor param 0.76, fill param 5, score: 0.7816
# CNV_multiples: Tiff CNV010_20210606_137_t49 segmented (Tiff n°16), gabor param 0.76, fill param 5, score: 0.8788
# CNV_multiples: Tiff CNV010_20210606_156_t7 segmented (Tiff n°17), gabor param 0.76, fill param 5, score: 0.8238
# CNV_multiples: Tiff CNV010_20210606_156_t31 segmented (Tiff n°18), gabor param 0.76, fill param 5, score: 0.7759
# CNV_multiples: Tiff CNV010_20210606_156_t49 segmented (Tiff n°19), gabor param 0.76, fill param 5, score: 0.6388
# CNV_multiples: Tiff CNV011_20210612_205_t25 segmented (Tiff n°20), gabor param 0.76, fill param 5, score: 0.7994
# CNV_multiples: Tiff CNV011_20210612_205_t49 segmented (Tiff n°21), gabor param 0.76, fill param 5, score: 0.6593
# CNV_multiples: Tiff CNV011_20210612_221_t49 segmented (Tiff n°22), gabor param 0.76, fill param 5, score: 0.7586
# CNV_multiples: Tiff CNV012_20210618_409_t49 segmented (Tiff n°23), gabor param 0.76, fill param 5, score: 0.8664
# CNV_multiples: Tiff CNV012_20210618_410_t1 segmented (Tiff n°24), gabor param 0.76, fill param 5, score: 0.8837
# CNV_multiples: Tiff CNV015_20210717_108_t1 segmented (Tiff n°25), gabor param 0.76, fill param 5, score: 0.849
# CNV_multiples: Tiff CNV015_20210717_108_t13 segmented (Tiff n°26), gabor param 0.76, fill param 5, score: 0.9049
# CNV_multiples: Tiff CNV015_20210717_108_t22 segmented (Tiff n°27), gabor param 0.76, fill param 5, score: 0.8866
# CNV_multiples: Tiff CNV015_20210717_108_t23 segmented (Tiff n°28), gabor param 0.76, fill param 5, score: 0.9022
# CNV_multiples: Tiff CNV015_20210717_108_t24 segmented (Tiff n°29), gabor param 0.76, fill param 5, score: 0.8804
# CNV_multiples: Tiff CNV015_20210717_108_t25 segmented (Tiff n°30), gabor param 0.76, fill param 5, score: 0.8954
# CNV_multiples: Tiff CNV015_20210717_110_25-0004 segmented (Tiff n°31), gabor param 0.76, fill param 5, score: 0.8062
# CNV_multiples: Tiff CNV015_20210717_110_25-0005 segmented (Tiff n°32), gabor param 0.76, fill param 5, score: 0.8425
# CNV_multiples: Tiff CNV015_20210717_110_25-0008 segmented (Tiff n°33), gabor param 0.76, fill param 5, score: 0.8571
# CNV_multiples: Tiff CNV015_20210717_110_25-0009 segmented (Tiff n°34), gabor param 0.76, fill param 5, score: 0.8573
# CNV_multiples: Tiff CNV015_20210717_110_25-0010 segmented (Tiff n°35), gabor param 0.76, fill param 5, score: 0.8264
# CNV_multiples: Tiff CNV015_20210717_110_25-0011 segmented (Tiff n°36), gabor param 0.76, fill param 5, score: 0.8169
# CNV_multiples: Tiff CNV015_20210717_110_25-0013 segmented (Tiff n°37), gabor param 0.76, fill param 5, score: 0.8276
# CNV_multiples: Tiff CNV015_20210717_110_25-0014 segmented (Tiff n°38), gabor param 0.76, fill param 5, score: 0.8157
# CNV_multiples: Tiff CNV015_20210717_110_25-0016 segmented (Tiff n°39), gabor param 0.76, fill param 5, score: 0.8157
# CNV_multiples: Tiff CNV015_20210717_110_25-0018 segmented (Tiff n°40), gabor param 0.76, fill param 5, score: 0.8333
# CNV_multiples: Tiff CNV015_20210717_110_25-0019 segmented (Tiff n°41), gabor param 0.76, fill param 5, score: 0.8088
# CNV_multiples: Tiff CNV015_20210717_110_25-0020 segmented (Tiff n°42), gabor param 0.76, fill param 5, score: 0.8036
# CNV_multiples: Tiff CNV015_20210717_110_25-0021 segmented (Tiff n°43), gabor param 0.76, fill param 5, score: 0.8011
# CNV_multiples: Tiff CNV015_20210717_110_25-0022 segmented (Tiff n°44), gabor param 0.76, fill param 5, score: 0.8249
# CNV_multiples: Tiff CNV015_20210717_110_25-0023 segmented (Tiff n°45), gabor param 0.76, fill param 5, score: 0.7941
# CNV_multiples: Tiff CNV015_20210717_110_25-0024 segmented (Tiff n°46), gabor param 0.76, fill param 5, score: 0.8374
# CNV_multiples: Tiff CNV015_20210717_118_t1 segmented (Tiff n°47), gabor param 0.76, fill param 5, score: 0.8353
# CNV_multiples: Tiff CNV015_20210717_118_t25 segmented (Tiff n°48), gabor param 0.76, fill param 5, score: 0.804
# CNV_multiples: Tiff CNV015_20210717_125_t1 segmented (Tiff n°49), gabor param 0.76, fill param 5, score: 0.8876
# CNV_multiples: Tiff CNV015_20210717_125_t13 segmented (Tiff n°50), gabor param 0.76, fill param 5, score: 0.8315
# CNV_multiples: Tiff CNV015_20210717_125_t25 segmented (Tiff n°51), gabor param 0.76, fill param 5, score: 0.8495
# CNV_multiples: Tiff CNV016_20210804_434_t49 segmented (Tiff n°52), gabor param 0.76, fill param 5, score: 0.7774
# CNV_multiples: Tiff CNV016_20210804_435_t49 segmented (Tiff n°53), gabor param 0.76, fill param 5, score: 0.714
# CNV_multiples: Tiff CNV016_20210804_440_t49 segmented (Tiff n°54), gabor param 0.76, fill param 5, score: 0.7721
# CNV_multiples: Tiff CNV016_20210804_441_t49 segmented (Tiff n°55), gabor param 0.76, fill param 5, score: 0.6622
# CNV_multiples: Tiff CNV016_20210804_442_t1 segmented (Tiff n°56), gabor param 0.76, fill param 5, score: 0.7819
# CNV_multiples: Tiff CNV016_20210804_442_t49 segmented (Tiff n°57), gabor param 0.76, fill param 5, score: 0.693
# CNV_multiples: Tiff CNV016_20210804_487_t1 segmented (Tiff n°58), gabor param 0.76, fill param 5, score: 0.8912
# CNV_multiples: Tiff CNV016_20210804_487_t25 segmented (Tiff n°59), gabor param 0.76, fill param 5, score: 0.8827
# CNV_multiples: Tiff CNV016_20210804_487_t49 segmented (Tiff n°60), gabor param 0.76, fill param 5, score: 0.7644
# CNV_multiples: Tiff CNV016_20210804_492_t25 segmented (Tiff n°61), gabor param 0.76, fill param 5, score: 0.8814
# CNV_multiples: Tiff CNV019_20210904_233_t49 segmented (Tiff n°62), gabor param 0.76, fill param 5, score: 0.8302
# CNV_multiples: Tiff CNV022_016_t1 segmented (Tiff n°63), gabor param 0.76, fill param 5, score: 0.8228
# CNV_multiples: Tiff CNV022_016_t25 segmented (Tiff n°64), gabor param 0.76, fill param 5, score: 0.7659
# CNV_multiples: Tiff CNV022_077_t25 segmented (Tiff n°65), gabor param 0.76, fill param 5, score: 0.759
# CNV_multiples: Tiff CNV022_077_t47 segmented (Tiff n°66), gabor param 0.76, fill param 5, score: 0.6808
# CNV_multiples: Tiff CNV022_077_t48 segmented (Tiff n°67), gabor param 0.76, fill param 5, score: 0.6855
# CNV_multiples: Tiff CNV022_077_t49 segmented (Tiff n°68), gabor param 0.76, fill param 5, score: 0.6714
# CNV_multiples: Tiff CNV026_136_t41 segmented (Tiff n°69), gabor param 0.76, fill param 5, score: 0.8505
# CNV_multiples: Tiff CNV026_141_t41 segmented (Tiff n°70), gabor param 0.76, fill param 5, score: 0.7031
# CNV_multiples: Tiff CNV028_38_t41 segmented (Tiff n°71), gabor param 0.76, fill param 5, score: 0.6428
# CNV_multiples: Tiff CNV028_40_t41 segmented (Tiff n°72), gabor param 0.76, fill param 5, score: 0.7238
# CNV_multiples: Tiff CNV028_80_t41 segmented (Tiff n°73), gabor param 0.76, fill param 5, score: 0.8032
# CNV_multiples: Tiff CNV028_82_t41 segmented (Tiff n°74), gabor param 0.76, fill param 5, score: 0.5962
# CNV_multiples: Tiff CNV049_20220610_200-0001 segmented (Tiff n°75), gabor param 0.76, fill param 5, score: 0.8976
# CNV_multiples: Tiff CNV049_20220610_200-0002 segmented (Tiff n°76), gabor param 0.76, fill param 5, score: 0.8994
# CNV_multiples: Tiff CNV049_20220610_200-0003 segmented (Tiff n°77), gabor param 0.76, fill param 5, score: 0.8988
# CNV_multiples: Tiff CNV049_20220610_200-0006 segmented (Tiff n°78), gabor param 0.76, fill param 5, score: 0.9035
# CNV_multiples: Tiff CNV049_20220610_200-0007 segmented (Tiff n°79), gabor param 0.76, fill param 5, score: 0.9281
# CNV_multiples: Tiff CNV049_20220610_200-0008 segmented (Tiff n°80), gabor param 0.76, fill param 5, score: 0.9208
# CNV_multiples: Tiff CNV049_20220610_200-0009 segmented (Tiff n°81), gabor param 0.76, fill param 5, score: 0.9183
# CNV_multiples: Tiff CNV049_20220610_200-0011 segmented (Tiff n°82), gabor param 0.76, fill param 5, score: 0.9219
# CNV_multiples: Tiff CNV049_20220610_200-0012 segmented (Tiff n°83), gabor param 0.76, fill param 5, score: 0.9074
# CNV_multiples: Tiff CNV049_20220610_200-0013 segmented (Tiff n°84), gabor param 0.76, fill param 5, score: 0.9087
# CNV_multiples: Tiff CNV049_20220610_200-0015 segmented (Tiff n°85), gabor param 0.76, fill param 5, score: 0.9255
# CNV_multiples: Tiff CNV049_20220610_200-0016 segmented (Tiff n°86), gabor param 0.76, fill param 5, score: 0.8924
# CNV_multiples: Tiff CNV049_20220610_200-0019 segmented (Tiff n°87), gabor param 0.76, fill param 5, score: 0.8845
# CNV_multiples: Tiff CNV049_20220610_200-0021 segmented (Tiff n°88), gabor param 0.76, fill param 5, score: 0.8634
# CNV_multiples: Tiff CNV049_20220610_200-0023 segmented (Tiff n°89), gabor param 0.76, fill param 5, score: 0.8645
# CNV_multiples: Tiff CNV049_20220610_200-0025 segmented (Tiff n°90), gabor param 0.76, fill param 5, score: 0.821
# CNV_multiples: Tiff CNV049_20220610_200-0026 segmented (Tiff n°91), gabor param 0.76, fill param 5, score: 0.8767
# CNV_multiples: Tiff CNV049_20220610_200-0028 segmented (Tiff n°92), gabor param 0.76, fill param 5, score: 0.8784
# CNV_multiples: Tiff CNV049_20220610_200-0032 segmented (Tiff n°93), gabor param 0.76, fill param 5, score: 0.8695
# CNV_multiples: Tiff CNV049_20220610_200-0033 segmented (Tiff n°94), gabor param 0.76, fill param 5, score: 0.8693
# CNV_multiples: Tiff CNV049_20220610_200-0034 segmented (Tiff n°95), gabor param 0.76, fill param 5, score: 0.8513
# CNV_multiples: Tiff CNV049_20220610_200-0035 segmented (Tiff n°96), gabor param 0.76, fill param 5, score: 0.9133
# CNV_multiples: Tiff CNV049_20220610_200-0036 segmented (Tiff n°97), gabor param 0.76, fill param 5, score: 0.854
# CNV_multiples: Tiff CNV049_20220610_200-0037 segmented (Tiff n°98), gabor param 0.76, fill param 5, score: 0.8689
# CNV_multiples: Tiff CNV049_20220610_200-0038 segmented (Tiff n°99), gabor param 0.76, fill param 5, score: 0.8819
# CNV_multiples: Tiff CNV049_20220610_200-0039 segmented (Tiff n°100), gabor param 0.76, fill param 5, score: 0.8961
# CNV_multiples: Tiff CNV049_20220610_200-0041 segmented (Tiff n°101), gabor param 0.76, fill param 5, score: 0.8779
# CNV_multiples: Tiff CNV049_20220610_200-0042 segmented (Tiff n°102), gabor param 0.76, fill param 5, score: 0.866
# CNV_multiples: Tiff CNV049_20220610_200-0043 segmented (Tiff n°103), gabor param 0.76, fill param 5, score: 0.8718
# CNV_multiples: Tiff CNV049_20220610_200-0044 segmented (Tiff n°104), gabor param 0.76, fill param 5, score: 0.8692
# CNV_multiples: Tiff CNV049_20220610_200-0045 segmented (Tiff n°105), gabor param 0.76, fill param 5, score: 0.8757
# CNV_multiples: Tiff CNV049_20220610_200-0047 segmented (Tiff n°106), gabor param 0.76, fill param 5, score: 0.8649
# CNV_multiples: Tiff CNV049_20220610_200-0048 segmented (Tiff n°107), gabor param 0.76, fill param 5, score: 0.8798
# CNV_multiples: Tiff CNV062_096_t48 segmented (Tiff n°108), gabor param 0.76, fill param 5, score: 0.7038
# CNV_multiples: Tiff CNV062_119_t48 segmented (Tiff n°109), gabor param 0.76, fill param 5, score: 0.5844
# CNV_multiples: Tiff CNV062_208_t48 segmented (Tiff n°110), gabor param 0.76, fill param 5, score: 0.8115
# CNV_multiples: Tiff CNV062_211_t19 segmented (Tiff n°111), gabor param 0.76, fill param 5, score: 0.8423
# CNV_multiples: Tiff CNV062_211_t48 segmented (Tiff n°112), gabor param 0.76, fill param 5, score: 0.8533
# CNV_multiples: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.77, fill param 5, score: 0.884
# CNV_multiples: Tiff CNV006_20210430_791_t8 segmented (Tiff n°2), gabor param 0.77, fill param 5, score: 0.8543
# CNV_multiples: Tiff CNV006_20210430_793_t8 segmented (Tiff n°3), gabor param 0.77, fill param 5, score: 0.6789
# CNV_multiples: Tiff CNV010_20210606_065_t1 segmented (Tiff n°4), gabor param 0.77, fill param 5, score: 0.8954
# CNV_multiples: Tiff CNV010_20210606_065_t25 segmented (Tiff n°5), gabor param 0.77, fill param 5, score: 0.7749
# CNV_multiples: Tiff CNV010_20210606_066_t1 segmented (Tiff n°6), gabor param 0.77, fill param 5, score: 0.8386
# CNV_multiples: Tiff CNV010_20210606_066_t24 segmented (Tiff n°7), gabor param 0.77, fill param 5, score: 0.9025
# CNV_multiples: Tiff CNV010_20210606_067_t1 segmented (Tiff n°8), gabor param 0.77, fill param 5, score: 0.9203
# CNV_multiples: Tiff CNV010_20210606_095_t7 segmented (Tiff n°9), gabor param 0.77, fill param 5, score: 0.8927
# CNV_multiples: Tiff CNV010_20210606_095_t31 segmented (Tiff n°10), gabor param 0.77, fill param 5, score: 0.8971
# CNV_multiples: Tiff CNV010_20210606_095_t49 segmented (Tiff n°11), gabor param 0.77, fill param 5, score: 0.9134
# CNV_multiples: Tiff CNV010_20210606_111_t31 segmented (Tiff n°12), gabor param 0.77, fill param 5, score: 0.8532
# CNV_multiples: Tiff CNV010_20210606_111_t49 segmented (Tiff n°13), gabor param 0.77, fill param 5, score: 0.8813
# CNV_multiples: Tiff CNV010_20210606_137_t7 segmented (Tiff n°14), gabor param 0.77, fill param 5, score: 0.8859
# CNV_multiples: Tiff CNV010_20210606_137_t31 segmented (Tiff n°15), gabor param 0.77, fill param 5, score: 0.7812
# CNV_multiples: Tiff CNV010_20210606_137_t49 segmented (Tiff n°16), gabor param 0.77, fill param 5, score: 0.879
# CNV_multiples: Tiff CNV010_20210606_156_t7 segmented (Tiff n°17), gabor param 0.77, fill param 5, score: 0.8235
# CNV_multiples: Tiff CNV010_20210606_156_t31 segmented (Tiff n°18), gabor param 0.77, fill param 5, score: 0.7616
# CNV_multiples: Tiff CNV010_20210606_156_t49 segmented (Tiff n°19), gabor param 0.77, fill param 5, score: 0.6396
# CNV_multiples: Tiff CNV011_20210612_205_t25 segmented (Tiff n°20), gabor param 0.77, fill param 5, score: 0.7986
# CNV_multiples: Tiff CNV011_20210612_205_t49 segmented (Tiff n°21), gabor param 0.77, fill param 5, score: 0.6594
# CNV_multiples: Tiff CNV011_20210612_221_t49 segmented (Tiff n°22), gabor param 0.77, fill param 5, score: 0.7589
# CNV_multiples: Tiff CNV012_20210618_409_t49 segmented (Tiff n°23), gabor param 0.77, fill param 5, score: 0.8663
# CNV_multiples: Tiff CNV012_20210618_410_t1 segmented (Tiff n°24), gabor param 0.77, fill param 5, score: 0.8841
# CNV_multiples: Tiff CNV015_20210717_108_t1 segmented (Tiff n°25), gabor param 0.77, fill param 5, score: 0.8493
# CNV_multiples: Tiff CNV015_20210717_108_t13 segmented (Tiff n°26), gabor param 0.77, fill param 5, score: 0.9054
# CNV_multiples: Tiff CNV015_20210717_108_t22 segmented (Tiff n°27), gabor param 0.77, fill param 5, score: 0.8837
# CNV_multiples: Tiff CNV015_20210717_108_t23 segmented (Tiff n°28), gabor param 0.77, fill param 5, score: 0.9024
# CNV_multiples: Tiff CNV015_20210717_108_t24 segmented (Tiff n°29), gabor param 0.77, fill param 5, score: 0.8835
# CNV_multiples: Tiff CNV015_20210717_108_t25 segmented (Tiff n°30), gabor param 0.77, fill param 5, score: 0.8991
# CNV_multiples: Tiff CNV015_20210717_110_25-0004 segmented (Tiff n°31), gabor param 0.77, fill param 5, score: 0.8065
# CNV_multiples: Tiff CNV015_20210717_110_25-0005 segmented (Tiff n°32), gabor param 0.77, fill param 5, score: 0.8427
# CNV_multiples: Tiff CNV015_20210717_110_25-0008 segmented (Tiff n°33), gabor param 0.77, fill param 5, score: 0.8571
# CNV_multiples: Tiff CNV015_20210717_110_25-0009 segmented (Tiff n°34), gabor param 0.77, fill param 5, score: 0.8577
# CNV_multiples: Tiff CNV015_20210717_110_25-0010 segmented (Tiff n°35), gabor param 0.77, fill param 5, score: 0.8266
# CNV_multiples: Tiff CNV015_20210717_110_25-0011 segmented (Tiff n°36), gabor param 0.77, fill param 5, score: 0.8167
# CNV_multiples: Tiff CNV015_20210717_110_25-0013 segmented (Tiff n°37), gabor param 0.77, fill param 5, score: 0.8277
# CNV_multiples: Tiff CNV015_20210717_110_25-0014 segmented (Tiff n°38), gabor param 0.77, fill param 5, score: 0.8152
# CNV_multiples: Tiff CNV015_20210717_110_25-0016 segmented (Tiff n°39), gabor param 0.77, fill param 5, score: 0.8157
# CNV_multiples: Tiff CNV015_20210717_110_25-0018 segmented (Tiff n°40), gabor param 0.77, fill param 5, score: 0.8321
# CNV_multiples: Tiff CNV015_20210717_110_25-0019 segmented (Tiff n°41), gabor param 0.77, fill param 5, score: 0.8086
# CNV_multiples: Tiff CNV015_20210717_110_25-0020 segmented (Tiff n°42), gabor param 0.77, fill param 5, score: 0.804
# CNV_multiples: Tiff CNV015_20210717_110_25-0021 segmented (Tiff n°43), gabor param 0.77, fill param 5, score: 0.8011
# CNV_multiples: Tiff CNV015_20210717_110_25-0022 segmented (Tiff n°44), gabor param 0.77, fill param 5, score: 0.8251
# CNV_multiples: Tiff CNV015_20210717_110_25-0023 segmented (Tiff n°45), gabor param 0.77, fill param 5, score: 0.7936
# CNV_multiples: Tiff CNV015_20210717_110_25-0024 segmented (Tiff n°46), gabor param 0.77, fill param 5, score: 0.8375
# CNV_multiples: Tiff CNV015_20210717_118_t1 segmented (Tiff n°47), gabor param 0.77, fill param 5, score: 0.8353
# CNV_multiples: Tiff CNV015_20210717_118_t25 segmented (Tiff n°48), gabor param 0.77, fill param 5, score: 0.8041
# CNV_multiples: Tiff CNV015_20210717_125_t1 segmented (Tiff n°49), gabor param 0.77, fill param 5, score: 0.8879
# CNV_multiples: Tiff CNV015_20210717_125_t13 segmented (Tiff n°50), gabor param 0.77, fill param 5, score: 0.8318
# CNV_multiples: Tiff CNV015_20210717_125_t25 segmented (Tiff n°51), gabor param 0.77, fill param 5, score: 0.8497
# CNV_multiples: Tiff CNV016_20210804_434_t49 segmented (Tiff n°52), gabor param 0.77, fill param 5, score: 0.7754
# CNV_multiples: Tiff CNV016_20210804_435_t49 segmented (Tiff n°53), gabor param 0.77, fill param 5, score: 0.7148
# CNV_multiples: Tiff CNV016_20210804_440_t49 segmented (Tiff n°54), gabor param 0.77, fill param 5, score: 0.7719
# CNV_multiples: Tiff CNV016_20210804_441_t49 segmented (Tiff n°55), gabor param 0.77, fill param 5, score: 0.6629
# CNV_multiples: Tiff CNV016_20210804_442_t1 segmented (Tiff n°56), gabor param 0.77, fill param 5, score: 0.7822
# CNV_multiples: Tiff CNV016_20210804_442_t49 segmented (Tiff n°57), gabor param 0.77, fill param 5, score: 0.6945
# CNV_multiples: Tiff CNV016_20210804_487_t1 segmented (Tiff n°58), gabor param 0.77, fill param 5, score: 0.8912
# CNV_multiples: Tiff CNV016_20210804_487_t25 segmented (Tiff n°59), gabor param 0.77, fill param 5, score: 0.8833
# CNV_multiples: Tiff CNV016_20210804_487_t49 segmented (Tiff n°60), gabor param 0.77, fill param 5, score: 0.7647
# CNV_multiples: Tiff CNV016_20210804_492_t25 segmented (Tiff n°61), gabor param 0.77, fill param 5, score: 0.8814
# CNV_multiples: Tiff CNV019_20210904_233_t49 segmented (Tiff n°62), gabor param 0.77, fill param 5, score: 0.8303
# CNV_multiples: Tiff CNV022_016_t1 segmented (Tiff n°63), gabor param 0.77, fill param 5, score: 0.8323
# CNV_multiples: Tiff CNV022_016_t25 segmented (Tiff n°64), gabor param 0.77, fill param 5, score: 0.7659
# CNV_multiples: Tiff CNV022_077_t25 segmented (Tiff n°65), gabor param 0.77, fill param 5, score: 0.7572
# CNV_multiples: Tiff CNV022_077_t47 segmented (Tiff n°66), gabor param 0.77, fill param 5, score: 0.6808
# CNV_multiples: Tiff CNV022_077_t48 segmented (Tiff n°67), gabor param 0.77, fill param 5, score: 0.6854
# CNV_multiples: Tiff CNV022_077_t49 segmented (Tiff n°68), gabor param 0.77, fill param 5, score: 0.6715
# CNV_multiples: Tiff CNV026_136_t41 segmented (Tiff n°69), gabor param 0.77, fill param 5, score: 0.853
# CNV_multiples: Tiff CNV026_141_t41 segmented (Tiff n°70), gabor param 0.77, fill param 5, score: 0.6858
# CNV_multiples: Tiff CNV028_38_t41 segmented (Tiff n°71), gabor param 0.77, fill param 5, score: 0.643
# CNV_multiples: Tiff CNV028_40_t41 segmented (Tiff n°72), gabor param 0.77, fill param 5, score: 0.7237
# CNV_multiples: Tiff CNV028_80_t41 segmented (Tiff n°73), gabor param 0.77, fill param 5, score: 0.803
# CNV_multiples: Tiff CNV028_82_t41 segmented (Tiff n°74), gabor param 0.77, fill param 5, score: 0.5962
# CNV_multiples: Tiff CNV049_20220610_200-0001 segmented (Tiff n°75), gabor param 0.77, fill param 5, score: 0.8971
# CNV_multiples: Tiff CNV049_20220610_200-0002 segmented (Tiff n°76), gabor param 0.77, fill param 5, score: 0.8992
# CNV_multiples: Tiff CNV049_20220610_200-0003 segmented (Tiff n°77), gabor param 0.77, fill param 5, score: 0.8989
# CNV_multiples: Tiff CNV049_20220610_200-0006 segmented (Tiff n°78), gabor param 0.77, fill param 5, score: 0.9047
# CNV_multiples: Tiff CNV049_20220610_200-0007 segmented (Tiff n°79), gabor param 0.77, fill param 5, score: 0.928
# CNV_multiples: Tiff CNV049_20220610_200-0008 segmented (Tiff n°80), gabor param 0.77, fill param 5, score: 0.9208
# CNV_multiples: Tiff CNV049_20220610_200-0009 segmented (Tiff n°81), gabor param 0.77, fill param 5, score: 0.9182
# CNV_multiples: Tiff CNV049_20220610_200-0011 segmented (Tiff n°82), gabor param 0.77, fill param 5, score: 0.922
# CNV_multiples: Tiff CNV049_20220610_200-0012 segmented (Tiff n°83), gabor param 0.77, fill param 5, score: 0.9074
# CNV_multiples: Tiff CNV049_20220610_200-0013 segmented (Tiff n°84), gabor param 0.77, fill param 5, score: 0.9087
# CNV_multiples: Tiff CNV049_20220610_200-0015 segmented (Tiff n°85), gabor param 0.77, fill param 5, score: 0.9256
# CNV_multiples: Tiff CNV049_20220610_200-0016 segmented (Tiff n°86), gabor param 0.77, fill param 5, score: 0.8925
# CNV_multiples: Tiff CNV049_20220610_200-0019 segmented (Tiff n°87), gabor param 0.77, fill param 5, score: 0.8844
# CNV_multiples: Tiff CNV049_20220610_200-0021 segmented (Tiff n°88), gabor param 0.77, fill param 5, score: 0.8634
# CNV_multiples: Tiff CNV049_20220610_200-0023 segmented (Tiff n°89), gabor param 0.77, fill param 5, score: 0.8645
# CNV_multiples: Tiff CNV049_20220610_200-0025 segmented (Tiff n°90), gabor param 0.77, fill param 5, score: 0.8212
# CNV_multiples: Tiff CNV049_20220610_200-0026 segmented (Tiff n°91), gabor param 0.77, fill param 5, score: 0.8767
# CNV_multiples: Tiff CNV049_20220610_200-0028 segmented (Tiff n°92), gabor param 0.77, fill param 5, score: 0.8784
# CNV_multiples: Tiff CNV049_20220610_200-0032 segmented (Tiff n°93), gabor param 0.77, fill param 5, score: 0.874
# CNV_multiples: Tiff CNV049_20220610_200-0033 segmented (Tiff n°94), gabor param 0.77, fill param 5, score: 0.8695
# CNV_multiples: Tiff CNV049_20220610_200-0034 segmented (Tiff n°95), gabor param 0.77, fill param 5, score: 0.8501
# CNV_multiples: Tiff CNV049_20220610_200-0035 segmented (Tiff n°96), gabor param 0.77, fill param 5, score: 0.9133
# CNV_multiples: Tiff CNV049_20220610_200-0036 segmented (Tiff n°97), gabor param 0.77, fill param 5, score: 0.8541
# CNV_multiples: Tiff CNV049_20220610_200-0037 segmented (Tiff n°98), gabor param 0.77, fill param 5, score: 0.8689
# CNV_multiples: Tiff CNV049_20220610_200-0038 segmented (Tiff n°99), gabor param 0.77, fill param 5, score: 0.8821
# CNV_multiples: Tiff CNV049_20220610_200-0039 segmented (Tiff n°100), gabor param 0.77, fill param 5, score: 0.8964
# CNV_multiples: Tiff CNV049_20220610_200-0041 segmented (Tiff n°101), gabor param 0.77, fill param 5, score: 0.8777
# CNV_multiples: Tiff CNV049_20220610_200-0042 segmented (Tiff n°102), gabor param 0.77, fill param 5, score: 0.8664
# CNV_multiples: Tiff CNV049_20220610_200-0043 segmented (Tiff n°103), gabor param 0.77, fill param 5, score: 0.8719
# CNV_multiples: Tiff CNV049_20220610_200-0044 segmented (Tiff n°104), gabor param 0.77, fill param 5, score: 0.8692
# CNV_multiples: Tiff CNV049_20220610_200-0045 segmented (Tiff n°105), gabor param 0.77, fill param 5, score: 0.8756
# CNV_multiples: Tiff CNV049_20220610_200-0047 segmented (Tiff n°106), gabor param 0.77, fill param 5, score: 0.8649
# CNV_multiples: Tiff CNV049_20220610_200-0048 segmented (Tiff n°107), gabor param 0.77, fill param 5, score: 0.8798
# CNV_multiples: Tiff CNV062_096_t48 segmented (Tiff n°108), gabor param 0.77, fill param 5, score: 0.7029
# CNV_multiples: Tiff CNV062_119_t48 segmented (Tiff n°109), gabor param 0.77, fill param 5, score: 0.5845
# CNV_multiples: Tiff CNV062_208_t48 segmented (Tiff n°110), gabor param 0.77, fill param 5, score: 0.8119
# CNV_multiples: Tiff CNV062_211_t19 segmented (Tiff n°111), gabor param 0.77, fill param 5, score: 0.8426
# CNV_multiples: Tiff CNV062_211_t48 segmented (Tiff n°112), gabor param 0.77, fill param 5, score: 0.8535
# CNV_multiples: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.78, fill param 5, score: 0.8842
# CNV_multiples: Tiff CNV006_20210430_791_t8 segmented (Tiff n°2), gabor param 0.78, fill param 5, score: 0.856
# CNV_multiples: Tiff CNV006_20210430_793_t8 segmented (Tiff n°3), gabor param 0.78, fill param 5, score: 0.7896
# CNV_multiples: Tiff CNV010_20210606_065_t1 segmented (Tiff n°4), gabor param 0.78, fill param 5, score: 0.8955
# CNV_multiples: Tiff CNV010_20210606_065_t25 segmented (Tiff n°5), gabor param 0.78, fill param 5, score: 0.7732
# CNV_multiples: Tiff CNV010_20210606_066_t1 segmented (Tiff n°6), gabor param 0.78, fill param 5, score: 0.8395
# CNV_multiples: Tiff CNV010_20210606_066_t24 segmented (Tiff n°7), gabor param 0.78, fill param 5, score: 0.9027
# CNV_multiples: Tiff CNV010_20210606_067_t1 segmented (Tiff n°8), gabor param 0.78, fill param 5, score: 0.9203
# CNV_multiples: Tiff CNV010_20210606_095_t7 segmented (Tiff n°9), gabor param 0.78, fill param 5, score: 0.8922
# CNV_multiples: Tiff CNV010_20210606_095_t31 segmented (Tiff n°10), gabor param 0.78, fill param 5, score: 0.8971
# CNV_multiples: Tiff CNV010_20210606_095_t49 segmented (Tiff n°11), gabor param 0.78, fill param 5, score: 0.914
# CNV_multiples: Tiff CNV010_20210606_111_t31 segmented (Tiff n°12), gabor param 0.78, fill param 5, score: 0.8533
# CNV_multiples: Tiff CNV010_20210606_111_t49 segmented (Tiff n°13), gabor param 0.78, fill param 5, score: 0.882
# CNV_multiples: Tiff CNV010_20210606_137_t7 segmented (Tiff n°14), gabor param 0.78, fill param 5, score: 0.8861
# CNV_multiples: Tiff CNV010_20210606_137_t31 segmented (Tiff n°15), gabor param 0.78, fill param 5, score: 0.7819
# CNV_multiples: Tiff CNV010_20210606_137_t49 segmented (Tiff n°16), gabor param 0.78, fill param 5, score: 0.8794
# CNV_multiples: Tiff CNV010_20210606_156_t7 segmented (Tiff n°17), gabor param 0.78, fill param 5, score: 0.8233
# CNV_multiples: Tiff CNV010_20210606_156_t31 segmented (Tiff n°18), gabor param 0.78, fill param 5, score: 0.7599
# CNV_multiples: Tiff CNV010_20210606_156_t49 segmented (Tiff n°19), gabor param 0.78, fill param 5, score: 0.6378
# CNV_multiples: Tiff CNV011_20210612_205_t25 segmented (Tiff n°20), gabor param 0.78, fill param 5, score: 0.8
# CNV_multiples: Tiff CNV011_20210612_205_t49 segmented (Tiff n°21), gabor param 0.78, fill param 5, score: 0.6599
# CNV_multiples: Tiff CNV011_20210612_221_t49 segmented (Tiff n°22), gabor param 0.78, fill param 5, score: 0.7595
# CNV_multiples: Tiff CNV012_20210618_409_t49 segmented (Tiff n°23), gabor param 0.78, fill param 5, score: 0.867
# CNV_multiples: Tiff CNV012_20210618_410_t1 segmented (Tiff n°24), gabor param 0.78, fill param 5, score: 0.8845
# CNV_multiples: Tiff CNV015_20210717_108_t1 segmented (Tiff n°25), gabor param 0.78, fill param 5, score: 0.8506
# CNV_multiples: Tiff CNV015_20210717_108_t13 segmented (Tiff n°26), gabor param 0.78, fill param 5, score: 0.906
# CNV_multiples: Tiff CNV015_20210717_108_t22 segmented (Tiff n°27), gabor param 0.78, fill param 5, score: 0.8843
# CNV_multiples: Tiff CNV015_20210717_108_t23 segmented (Tiff n°28), gabor param 0.78, fill param 5, score: 0.9027
# CNV_multiples: Tiff CNV015_20210717_108_t24 segmented (Tiff n°29), gabor param 0.78, fill param 5, score: 0.8799
# CNV_multiples: Tiff CNV015_20210717_108_t25 segmented (Tiff n°30), gabor param 0.78, fill param 5, score: 0.8991
# CNV_multiples: Tiff CNV015_20210717_110_25-0004 segmented (Tiff n°31), gabor param 0.78, fill param 5, score: 0.8037
# CNV_multiples: Tiff CNV015_20210717_110_25-0005 segmented (Tiff n°32), gabor param 0.78, fill param 5, score: 0.8432
# CNV_multiples: Tiff CNV015_20210717_110_25-0008 segmented (Tiff n°33), gabor param 0.78, fill param 5, score: 0.8572
# CNV_multiples: Tiff CNV015_20210717_110_25-0009 segmented (Tiff n°34), gabor param 0.78, fill param 5, score: 0.8583
# CNV_multiples: Tiff CNV015_20210717_110_25-0010 segmented (Tiff n°35), gabor param 0.78, fill param 5, score: 0.8265
# CNV_multiples: Tiff CNV015_20210717_110_25-0011 segmented (Tiff n°36), gabor param 0.78, fill param 5, score: 0.8184
# CNV_multiples: Tiff CNV015_20210717_110_25-0013 segmented (Tiff n°37), gabor param 0.78, fill param 5, score: 0.8279
# CNV_multiples: Tiff CNV015_20210717_110_25-0014 segmented (Tiff n°38), gabor param 0.78, fill param 5, score: 0.8162
# CNV_multiples: Tiff CNV015_20210717_110_25-0016 segmented (Tiff n°39), gabor param 0.78, fill param 5, score: 0.8162
# CNV_multiples: Tiff CNV015_20210717_110_25-0018 segmented (Tiff n°40), gabor param 0.78, fill param 5, score: 0.7979
# CNV_multiples: Tiff CNV015_20210717_110_25-0019 segmented (Tiff n°41), gabor param 0.78, fill param 5, score: 0.8109
# CNV_multiples: Tiff CNV015_20210717_110_25-0020 segmented (Tiff n°42), gabor param 0.78, fill param 5, score: 0.8099
# CNV_multiples: Tiff CNV015_20210717_110_25-0021 segmented (Tiff n°43), gabor param 0.78, fill param 5, score: 0.8012
# CNV_multiples: Tiff CNV015_20210717_110_25-0022 segmented (Tiff n°44), gabor param 0.78, fill param 5, score: 0.8146
# CNV_multiples: Tiff CNV015_20210717_110_25-0023 segmented (Tiff n°45), gabor param 0.78, fill param 5, score: 0.7936
# CNV_multiples: Tiff CNV015_20210717_110_25-0024 segmented (Tiff n°46), gabor param 0.78, fill param 5, score: 0.8382
# CNV_multiples: Tiff CNV015_20210717_118_t1 segmented (Tiff n°47), gabor param 0.78, fill param 5, score: 0.8361
# CNV_multiples: Tiff CNV015_20210717_118_t25 segmented (Tiff n°48), gabor param 0.78, fill param 5, score: 0.8038
# CNV_multiples: Tiff CNV015_20210717_125_t1 segmented (Tiff n°49), gabor param 0.78, fill param 5, score: 0.8892
# CNV_multiples: Tiff CNV015_20210717_125_t13 segmented (Tiff n°50), gabor param 0.78, fill param 5, score: 0.8319
# CNV_multiples: Tiff CNV015_20210717_125_t25 segmented (Tiff n°51), gabor param 0.78, fill param 5, score: 0.8492
# CNV_multiples: Tiff CNV016_20210804_434_t49 segmented (Tiff n°52), gabor param 0.78, fill param 5, score: 0.7754
# CNV_multiples: Tiff CNV016_20210804_435_t49 segmented (Tiff n°53), gabor param 0.78, fill param 5, score: 0.7156
# CNV_multiples: Tiff CNV016_20210804_440_t49 segmented (Tiff n°54), gabor param 0.78, fill param 5, score: 0.7779
# CNV_multiples: Tiff CNV016_20210804_441_t49 segmented (Tiff n°55), gabor param 0.78, fill param 5, score: 0.6628
# CNV_multiples: Tiff CNV016_20210804_442_t1 segmented (Tiff n°56), gabor param 0.78, fill param 5, score: 0.7829
# CNV_multiples: Tiff CNV016_20210804_442_t49 segmented (Tiff n°57), gabor param 0.78, fill param 5, score: 0.695
# CNV_multiples: Tiff CNV016_20210804_487_t1 segmented (Tiff n°58), gabor param 0.78, fill param 5, score: 0.8918
# CNV_multiples: Tiff CNV016_20210804_487_t25 segmented (Tiff n°59), gabor param 0.78, fill param 5, score: 0.8837
# CNV_multiples: Tiff CNV016_20210804_487_t49 segmented (Tiff n°60), gabor param 0.78, fill param 5, score: 0.767
# CNV_multiples: Tiff CNV016_20210804_492_t25 segmented (Tiff n°61), gabor param 0.78, fill param 5, score: 0.8811
# CNV_multiples: Tiff CNV019_20210904_233_t49 segmented (Tiff n°62), gabor param 0.78, fill param 5, score: 0.8306
# CNV_multiples: Tiff CNV022_016_t1 segmented (Tiff n°63), gabor param 0.78, fill param 5, score: 0.8247
# CNV_multiples: Tiff CNV022_016_t25 segmented (Tiff n°64), gabor param 0.78, fill param 5, score: 0.7661
# CNV_multiples: Tiff CNV022_077_t25 segmented (Tiff n°65), gabor param 0.78, fill param 5, score: 0.7569
# CNV_multiples: Tiff CNV022_077_t47 segmented (Tiff n°66), gabor param 0.78, fill param 5, score: 0.6812
# CNV_multiples: Tiff CNV022_077_t48 segmented (Tiff n°67), gabor param 0.78, fill param 5, score: 0.6872
# CNV_multiples: Tiff CNV022_077_t49 segmented (Tiff n°68), gabor param 0.78, fill param 5, score: 0.6716
# CNV_multiples: Tiff CNV026_136_t41 segmented (Tiff n°69), gabor param 0.78, fill param 5, score: 0.8529
# CNV_multiples: Tiff CNV026_141_t41 segmented (Tiff n°70), gabor param 0.78, fill param 5, score: 0.6861
# CNV_multiples: Tiff CNV028_38_t41 segmented (Tiff n°71), gabor param 0.78, fill param 5, score: 0.6429
# CNV_multiples: Tiff CNV028_40_t41 segmented (Tiff n°72), gabor param 0.78, fill param 5, score: 0.7248
# CNV_multiples: Tiff CNV028_80_t41 segmented (Tiff n°73), gabor param 0.78, fill param 5, score: 0.8031
# CNV_multiples: Tiff CNV028_82_t41 segmented (Tiff n°74), gabor param 0.78, fill param 5, score: 0.5961
# CNV_multiples: Tiff CNV049_20220610_200-0001 segmented (Tiff n°75), gabor param 0.78, fill param 5, score: 0.8991
# CNV_multiples: Tiff CNV049_20220610_200-0002 segmented (Tiff n°76), gabor param 0.78, fill param 5, score: 0.8992
# CNV_multiples: Tiff CNV049_20220610_200-0003 segmented (Tiff n°77), gabor param 0.78, fill param 5, score: 0.899
# CNV_multiples: Tiff CNV049_20220610_200-0006 segmented (Tiff n°78), gabor param 0.78, fill param 5, score: 0.9047
# CNV_multiples: Tiff CNV049_20220610_200-0007 segmented (Tiff n°79), gabor param 0.78, fill param 5, score: 0.9281
# CNV_multiples: Tiff CNV049_20220610_200-0008 segmented (Tiff n°80), gabor param 0.78, fill param 5, score: 0.9208
# CNV_multiples: Tiff CNV049_20220610_200-0009 segmented (Tiff n°81), gabor param 0.78, fill param 5, score: 0.9183
# CNV_multiples: Tiff CNV049_20220610_200-0011 segmented (Tiff n°82), gabor param 0.78, fill param 5, score: 0.9209
# CNV_multiples: Tiff CNV049_20220610_200-0012 segmented (Tiff n°83), gabor param 0.78, fill param 5, score: 0.9075
# CNV_multiples: Tiff CNV049_20220610_200-0013 segmented (Tiff n°84), gabor param 0.78, fill param 5, score: 0.9089
# CNV_multiples: Tiff CNV049_20220610_200-0015 segmented (Tiff n°85), gabor param 0.78, fill param 5, score: 0.9292
# CNV_multiples: Tiff CNV049_20220610_200-0016 segmented (Tiff n°86), gabor param 0.78, fill param 5, score: 0.8933
# CNV_multiples: Tiff CNV049_20220610_200-0019 segmented (Tiff n°87), gabor param 0.78, fill param 5, score: 0.8845
# CNV_multiples: Tiff CNV049_20220610_200-0021 segmented (Tiff n°88), gabor param 0.78, fill param 5, score: 0.863
# CNV_multiples: Tiff CNV049_20220610_200-0023 segmented (Tiff n°89), gabor param 0.78, fill param 5, score: 0.8647
# CNV_multiples: Tiff CNV049_20220610_200-0025 segmented (Tiff n°90), gabor param 0.78, fill param 5, score: 0.8215
# CNV_multiples: Tiff CNV049_20220610_200-0026 segmented (Tiff n°91), gabor param 0.78, fill param 5, score: 0.8776
# CNV_multiples: Tiff CNV049_20220610_200-0028 segmented (Tiff n°92), gabor param 0.78, fill param 5, score: 0.8786
# CNV_multiples: Tiff CNV049_20220610_200-0032 segmented (Tiff n°93), gabor param 0.78, fill param 5, score: 0.8747
# CNV_multiples: Tiff CNV049_20220610_200-0033 segmented (Tiff n°94), gabor param 0.78, fill param 5, score: 0.8688
# CNV_multiples: Tiff CNV049_20220610_200-0034 segmented (Tiff n°95), gabor param 0.78, fill param 5, score: 0.8502
# CNV_multiples: Tiff CNV049_20220610_200-0035 segmented (Tiff n°96), gabor param 0.78, fill param 5, score: 0.9139
# CNV_multiples: Tiff CNV049_20220610_200-0036 segmented (Tiff n°97), gabor param 0.78, fill param 5, score: 0.8541
# CNV_multiples: Tiff CNV049_20220610_200-0037 segmented (Tiff n°98), gabor param 0.78, fill param 5, score: 0.8695
# CNV_multiples: Tiff CNV049_20220610_200-0038 segmented (Tiff n°99), gabor param 0.78, fill param 5, score: 0.882
# CNV_multiples: Tiff CNV049_20220610_200-0039 segmented (Tiff n°100), gabor param 0.78, fill param 5, score: 0.8965
# CNV_multiples: Tiff CNV049_20220610_200-0041 segmented (Tiff n°101), gabor param 0.78, fill param 5, score: 0.8777
# CNV_multiples: Tiff CNV049_20220610_200-0042 segmented (Tiff n°102), gabor param 0.78, fill param 5, score: 0.8665
# CNV_multiples: Tiff CNV049_20220610_200-0043 segmented (Tiff n°103), gabor param 0.78, fill param 5, score: 0.8722
# CNV_multiples: Tiff CNV049_20220610_200-0044 segmented (Tiff n°104), gabor param 0.78, fill param 5, score: 0.8693
# CNV_multiples: Tiff CNV049_20220610_200-0045 segmented (Tiff n°105), gabor param 0.78, fill param 5, score: 0.875
# CNV_multiples: Tiff CNV049_20220610_200-0047 segmented (Tiff n°106), gabor param 0.78, fill param 5, score: 0.8648
# CNV_multiples: Tiff CNV049_20220610_200-0048 segmented (Tiff n°107), gabor param 0.78, fill param 5, score: 0.88
# CNV_multiples: Tiff CNV062_096_t48 segmented (Tiff n°108), gabor param 0.78, fill param 5, score: 0.7012
# CNV_multiples: Tiff CNV062_119_t48 segmented (Tiff n°109), gabor param 0.78, fill param 5, score: 0.6012
# CNV_multiples: Tiff CNV062_208_t48 segmented (Tiff n°110), gabor param 0.78, fill param 5, score: 0.8128
# CNV_multiples: Tiff CNV062_211_t19 segmented (Tiff n°111), gabor param 0.78, fill param 5, score: 0.8433
# CNV_multiples: Tiff CNV062_211_t48 segmented (Tiff n°112), gabor param 0.78, fill param 5, score: 0.8529
# CNV_multiples: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.79, fill param 5, score: 0.8851
# CNV_multiples: Tiff CNV006_20210430_791_t8 segmented (Tiff n°2), gabor param 0.79, fill param 5, score: 0.8553
# CNV_multiples: Tiff CNV006_20210430_793_t8 segmented (Tiff n°3), gabor param 0.79, fill param 5, score: 0.7895
# CNV_multiples: Tiff CNV010_20210606_065_t1 segmented (Tiff n°4), gabor param 0.79, fill param 5, score: 0.896
# CNV_multiples: Tiff CNV010_20210606_065_t25 segmented (Tiff n°5), gabor param 0.79, fill param 5, score: 0.7735
# CNV_multiples: Tiff CNV010_20210606_066_t1 segmented (Tiff n°6), gabor param 0.79, fill param 5, score: 0.84
# CNV_multiples: Tiff CNV010_20210606_066_t24 segmented (Tiff n°7), gabor param 0.79, fill param 5, score: 0.9019
# CNV_multiples: Tiff CNV010_20210606_067_t1 segmented (Tiff n°8), gabor param 0.79, fill param 5, score: 0.9213
# CNV_multiples: Tiff CNV010_20210606_095_t7 segmented (Tiff n°9), gabor param 0.79, fill param 5, score: 0.8904
# CNV_multiples: Tiff CNV010_20210606_095_t31 segmented (Tiff n°10), gabor param 0.79, fill param 5, score: 0.8975
# CNV_multiples: Tiff CNV010_20210606_095_t49 segmented (Tiff n°11), gabor param 0.79, fill param 5, score: 0.9139
# CNV_multiples: Tiff CNV010_20210606_111_t31 segmented (Tiff n°12), gabor param 0.79, fill param 5, score: 0.8496
# CNV_multiples: Tiff CNV010_20210606_111_t49 segmented (Tiff n°13), gabor param 0.79, fill param 5, score: 0.8801
# CNV_multiples: Tiff CNV010_20210606_137_t7 segmented (Tiff n°14), gabor param 0.79, fill param 5, score: 0.8867
# CNV_multiples: Tiff CNV010_20210606_137_t31 segmented (Tiff n°15), gabor param 0.79, fill param 5, score: 0.7828
# CNV_multiples: Tiff CNV010_20210606_137_t49 segmented (Tiff n°16), gabor param 0.79, fill param 5, score: 0.8775
# CNV_multiples: Tiff CNV010_20210606_156_t7 segmented (Tiff n°17), gabor param 0.79, fill param 5, score: 0.8233
# CNV_multiples: Tiff CNV010_20210606_156_t31 segmented (Tiff n°18), gabor param 0.79, fill param 5, score: 0.7596
# CNV_multiples: Tiff CNV010_20210606_156_t49 segmented (Tiff n°19), gabor param 0.79, fill param 5, score: 0.5858
# CNV_multiples: Tiff CNV011_20210612_205_t25 segmented (Tiff n°20), gabor param 0.79, fill param 5, score: 0.8028
# CNV_multiples: Tiff CNV011_20210612_205_t49 segmented (Tiff n°21), gabor param 0.79, fill param 5, score: 0.6621
# CNV_multiples: Tiff CNV011_20210612_221_t49 segmented (Tiff n°22), gabor param 0.79, fill param 5, score: 0.7614
# CNV_multiples: Tiff CNV012_20210618_409_t49 segmented (Tiff n°23), gabor param 0.79, fill param 5, score: 0.8675
# CNV_multiples: Tiff CNV012_20210618_410_t1 segmented (Tiff n°24), gabor param 0.79, fill param 5, score: 0.885
# CNV_multiples: Tiff CNV015_20210717_108_t1 segmented (Tiff n°25), gabor param 0.79, fill param 5, score: 0.8525
# CNV_multiples: Tiff CNV015_20210717_108_t13 segmented (Tiff n°26), gabor param 0.79, fill param 5, score: 0.9067
# CNV_multiples: Tiff CNV015_20210717_108_t22 segmented (Tiff n°27), gabor param 0.79, fill param 5, score: 0.8851
# CNV_multiples: Tiff CNV015_20210717_108_t23 segmented (Tiff n°28), gabor param 0.79, fill param 5, score: 0.9034
# CNV_multiples: Tiff CNV015_20210717_108_t24 segmented (Tiff n°29), gabor param 0.79, fill param 5, score: 0.8791
# CNV_multiples: Tiff CNV015_20210717_108_t25 segmented (Tiff n°30), gabor param 0.79, fill param 5, score: 0.8943
# CNV_multiples: Tiff CNV015_20210717_110_25-0004 segmented (Tiff n°31), gabor param 0.79, fill param 5, score: 0.8054
# CNV_multiples: Tiff CNV015_20210717_110_25-0005 segmented (Tiff n°32), gabor param 0.79, fill param 5, score: 0.8438
# CNV_multiples: Tiff CNV015_20210717_110_25-0008 segmented (Tiff n°33), gabor param 0.79, fill param 5, score: 0.8561
# CNV_multiples: Tiff CNV015_20210717_110_25-0009 segmented (Tiff n°34), gabor param 0.79, fill param 5, score: 0.8592
# CNV_multiples: Tiff CNV015_20210717_110_25-0010 segmented (Tiff n°35), gabor param 0.79, fill param 5, score: 0.8271
# CNV_multiples: Tiff CNV015_20210717_110_25-0011 segmented (Tiff n°36), gabor param 0.79, fill param 5, score: 0.8486
# CNV_multiples: Tiff CNV015_20210717_110_25-0013 segmented (Tiff n°37), gabor param 0.79, fill param 5, score: 0.8287
# CNV_multiples: Tiff CNV015_20210717_110_25-0014 segmented (Tiff n°38), gabor param 0.79, fill param 5, score: 0.8158
# CNV_multiples: Tiff CNV015_20210717_110_25-0016 segmented (Tiff n°39), gabor param 0.79, fill param 5, score: 0.8165
# CNV_multiples: Tiff CNV015_20210717_110_25-0018 segmented (Tiff n°40), gabor param 0.79, fill param 5, score: 0.8044
# CNV_multiples: Tiff CNV015_20210717_110_25-0019 segmented (Tiff n°41), gabor param 0.79, fill param 5, score: 0.8056
# CNV_multiples: Tiff CNV015_20210717_110_25-0020 segmented (Tiff n°42), gabor param 0.79, fill param 5, score: 0.8046
# CNV_multiples: Tiff CNV015_20210717_110_25-0021 segmented (Tiff n°43), gabor param 0.79, fill param 5, score: 0.7893
# CNV_multiples: Tiff CNV015_20210717_110_25-0022 segmented (Tiff n°44), gabor param 0.79, fill param 5, score: 0.8114
# CNV_multiples: Tiff CNV015_20210717_110_25-0023 segmented (Tiff n°45), gabor param 0.79, fill param 5, score: 0.7919
# CNV_multiples: Tiff CNV015_20210717_110_25-0024 segmented (Tiff n°46), gabor param 0.79, fill param 5, score: 0.8363
# CNV_multiples: Tiff CNV015_20210717_118_t1 segmented (Tiff n°47), gabor param 0.79, fill param 5, score: 0.837
# CNV_multiples: Tiff CNV015_20210717_118_t25 segmented (Tiff n°48), gabor param 0.79, fill param 5, score: 0.8048
# CNV_multiples: Tiff CNV015_20210717_125_t1 segmented (Tiff n°49), gabor param 0.79, fill param 5, score: 0.8897
# CNV_multiples: Tiff CNV015_20210717_125_t13 segmented (Tiff n°50), gabor param 0.79, fill param 5, score: 0.8318
# CNV_multiples: Tiff CNV015_20210717_125_t25 segmented (Tiff n°51), gabor param 0.79, fill param 5, score: 0.8491
# CNV_multiples: Tiff CNV016_20210804_434_t49 segmented (Tiff n°52), gabor param 0.79, fill param 5, score: 0.7761
# CNV_multiples: Tiff CNV016_20210804_435_t49 segmented (Tiff n°53), gabor param 0.79, fill param 5, score: 0.7171
# CNV_multiples: Tiff CNV016_20210804_440_t49 segmented (Tiff n°54), gabor param 0.79, fill param 5, score: 0.7793
# CNV_multiples: Tiff CNV016_20210804_441_t49 segmented (Tiff n°55), gabor param 0.79, fill param 5, score: 0.6633
# CNV_multiples: Tiff CNV016_20210804_442_t1 segmented (Tiff n°56), gabor param 0.79, fill param 5, score: 0.7831
# CNV_multiples: Tiff CNV016_20210804_442_t49 segmented (Tiff n°57), gabor param 0.79, fill param 5, score: 0.6957
# CNV_multiples: Tiff CNV016_20210804_487_t1 segmented (Tiff n°58), gabor param 0.79, fill param 5, score: 0.8931
# CNV_multiples: Tiff CNV016_20210804_487_t25 segmented (Tiff n°59), gabor param 0.79, fill param 5, score: 0.8842
# CNV_multiples: Tiff CNV016_20210804_487_t49 segmented (Tiff n°60), gabor param 0.79, fill param 5, score: 0.7685
# CNV_multiples: Tiff CNV016_20210804_492_t25 segmented (Tiff n°61), gabor param 0.79, fill param 5, score: 0.8811
# CNV_multiples: Tiff CNV019_20210904_233_t49 segmented (Tiff n°62), gabor param 0.79, fill param 5, score: 0.8321
# CNV_multiples: Tiff CNV022_016_t1 segmented (Tiff n°63), gabor param 0.79, fill param 5, score: 0.8248
# CNV_multiples: Tiff CNV022_016_t25 segmented (Tiff n°64), gabor param 0.79, fill param 5, score: 0.7657
# CNV_multiples: Tiff CNV022_077_t25 segmented (Tiff n°65), gabor param 0.79, fill param 5, score: 0.7574
# CNV_multiples: Tiff CNV022_077_t47 segmented (Tiff n°66), gabor param 0.79, fill param 5, score: 0.6814
# CNV_multiples: Tiff CNV022_077_t48 segmented (Tiff n°67), gabor param 0.79, fill param 5, score: 0.6872
# CNV_multiples: Tiff CNV022_077_t49 segmented (Tiff n°68), gabor param 0.79, fill param 5, score: 0.6591
# CNV_multiples: Tiff CNV026_136_t41 segmented (Tiff n°69), gabor param 0.79, fill param 5, score: 0.8546
# CNV_multiples: Tiff CNV026_141_t41 segmented (Tiff n°70), gabor param 0.79, fill param 5, score: 0.6873
# CNV_multiples: Tiff CNV028_38_t41 segmented (Tiff n°71), gabor param 0.79, fill param 5, score: 0.6427
# CNV_multiples: Tiff CNV028_40_t41 segmented (Tiff n°72), gabor param 0.79, fill param 5, score: 0.7298
# CNV_multiples: Tiff CNV028_80_t41 segmented (Tiff n°73), gabor param 0.79, fill param 5, score: 0.8039
# CNV_multiples: Tiff CNV028_82_t41 segmented (Tiff n°74), gabor param 0.79, fill param 5, score: 0.5792
# CNV_multiples: Tiff CNV049_20220610_200-0001 segmented (Tiff n°75), gabor param 0.79, fill param 5, score: 0.9
# CNV_multiples: Tiff CNV049_20220610_200-0002 segmented (Tiff n°76), gabor param 0.79, fill param 5, score: 0.8929
# CNV_multiples: Tiff CNV049_20220610_200-0003 segmented (Tiff n°77), gabor param 0.79, fill param 5, score: 0.9011
# CNV_multiples: Tiff CNV049_20220610_200-0006 segmented (Tiff n°78), gabor param 0.79, fill param 5, score: 0.903
# CNV_multiples: Tiff CNV049_20220610_200-0007 segmented (Tiff n°79), gabor param 0.79, fill param 5, score: 0.9288
# CNV_multiples: Tiff CNV049_20220610_200-0008 segmented (Tiff n°80), gabor param 0.79, fill param 5, score: 0.9209
# CNV_multiples: Tiff CNV049_20220610_200-0009 segmented (Tiff n°81), gabor param 0.79, fill param 5, score: 0.9212
# CNV_multiples: Tiff CNV049_20220610_200-0011 segmented (Tiff n°82), gabor param 0.79, fill param 5, score: 0.9233
# CNV_multiples: Tiff CNV049_20220610_200-0012 segmented (Tiff n°83), gabor param 0.79, fill param 5, score: 0.9075
# CNV_multiples: Tiff CNV049_20220610_200-0013 segmented (Tiff n°84), gabor param 0.79, fill param 5, score: 0.9089
# CNV_multiples: Tiff CNV049_20220610_200-0015 segmented (Tiff n°85), gabor param 0.79, fill param 5, score: 0.9293
# CNV_multiples: Tiff CNV049_20220610_200-0016 segmented (Tiff n°86), gabor param 0.79, fill param 5, score: 0.8938
# CNV_multiples: Tiff CNV049_20220610_200-0019 segmented (Tiff n°87), gabor param 0.79, fill param 5, score: 0.885
# CNV_multiples: Tiff CNV049_20220610_200-0021 segmented (Tiff n°88), gabor param 0.79, fill param 5, score: 0.8627
# CNV_multiples: Tiff CNV049_20220610_200-0023 segmented (Tiff n°89), gabor param 0.79, fill param 5, score: 0.8664
# CNV_multiples: Tiff CNV049_20220610_200-0025 segmented (Tiff n°90), gabor param 0.79, fill param 5, score: 0.8074
# CNV_multiples: Tiff CNV049_20220610_200-0026 segmented (Tiff n°91), gabor param 0.79, fill param 5, score: 0.8779
# ...
# CNV_multiples: Tiff CNV049_20220610_200-0028 segmented (Tiff n°92), gabor param 0.78, fill param 20, score: 0.8788
# CNV_multiples: Tiff CNV049_20220610_200-0032 segmented (Tiff n°93), gabor param 0.78, fill param 20, score: 0.8655
# CNV_multiples: Tiff CNV049_20220610_200-0033 segmented (Tiff n°94), gabor param 0.78, fill param 20, score: 0.8661
# CNV_multiples: Tiff CNV049_20220610_200-0034 segmented (Tiff n°95), gabor param 0.78, fill param 20, score: 0.8453
# CNV_multiples: Tiff CNV049_20220610_200-0035 segmented (Tiff n°96), gabor param 0.78, fill param 20, score: 0.9018
# CNV_multiples: Tiff CNV049_20220610_200-0036 segmented (Tiff n°97), gabor param 0.78, fill param 20, score: 0.837
# CNV_multiples: Tiff CNV049_20220610_200-0037 segmented (Tiff n°98), gabor param 0.78, fill param 20, score: 0.8549
# CNV_multiples: Tiff CNV049_20220610_200-0038 segmented (Tiff n°99), gabor param 0.78, fill param 20, score: 0.8646
# CNV_multiples: Tiff CNV049_20220610_200-0039 segmented (Tiff n°100), gabor param 0.78, fill param 20, score: 0.8907
# CNV_multiples: Tiff CNV049_20220610_200-0041 segmented (Tiff n°101), gabor param 0.78, fill param 20, score: 0.8644
# CNV_multiples: Tiff CNV049_20220610_200-0042 segmented (Tiff n°102), gabor param 0.78, fill param 20, score: 0.8428
# CNV_multiples: Tiff CNV049_20220610_200-0043 segmented (Tiff n°103), gabor param 0.78, fill param 20, score: 0.8458
# CNV_multiples: Tiff CNV049_20220610_200-0044 segmented (Tiff n°104), gabor param 0.78, fill param 20, score: 0.8546
# CNV_multiples: Tiff CNV049_20220610_200-0045 segmented (Tiff n°105), gabor param 0.78, fill param 20, score: 0.8731
# CNV_multiples: Tiff CNV049_20220610_200-0047 segmented (Tiff n°106), gabor param 0.78, fill param 20, score: 0.8444
# CNV_multiples: Tiff CNV049_20220610_200-0048 segmented (Tiff n°107), gabor param 0.78, fill param 20, score: 0.8779
# CNV_multiples: Tiff CNV062_096_t48 segmented (Tiff n°108), gabor param 0.78, fill param 20, score: 0.6747
# CNV_multiples: Tiff CNV062_119_t48 segmented (Tiff n°109), gabor param 0.78, fill param 20, score: 0.5254
# CNV_multiples: Tiff CNV062_208_t48 segmented (Tiff n°110), gabor param 0.78, fill param 20, score: 0.8234
# CNV_multiples: Tiff CNV062_211_t19 segmented (Tiff n°111), gabor param 0.78, fill param 20, score: 0.6351
# CNV_multiples: Tiff CNV062_211_t48 segmented (Tiff n°112), gabor param 0.78, fill param 20, score: 0.8414
# CNV_multiples: Tiff CNV006_20210430_782_t8 segmented (Tiff n°1), gabor param 0.79, fill param 20, score: 0.8377
# CNV_multiples: Tiff CNV006_20210430_791_t8 segmented (Tiff n°2), gabor param 0.79, fill param 20, score: 0.8468
# CNV_multiples: Tiff CNV006_20210430_793_t8 segmented (Tiff n°3), gabor param 0.79, fill param 20, score: 0.7177
# CNV_multiples: Tiff CNV010_20210606_065_t1 segmented (Tiff n°4), gabor param 0.79, fill param 20, score: 0.8807
# CNV_multiples: Tiff CNV010_20210606_065_t25 segmented (Tiff n°5), gabor param 0.79, fill param 20, score: 0.8489
# CNV_multiples: Tiff CNV010_20210606_066_t1 segmented (Tiff n°6), gabor param 0.79, fill param 20, score: 0.8283
# CNV_multiples: Tiff CNV010_20210606_066_t24 segmented (Tiff n°7), gabor param 0.79, fill param 20, score: 0.8832
# CNV_multiples: Tiff CNV010_20210606_067_t1 segmented (Tiff n°8), gabor param 0.79, fill param 20, score: 0.9136
# CNV_multiples: Tiff CNV010_20210606_095_t7 segmented (Tiff n°9), gabor param 0.79, fill param 20, score: 0.8854
# CNV_multiples: Tiff CNV010_20210606_095_t31 segmented (Tiff n°10), gabor param 0.79, fill param 20, score: 0.8798
# CNV_multiples: Tiff CNV010_20210606_095_t49 segmented (Tiff n°11), gabor param 0.79, fill param 20, score: 0.9018
# CNV_multiples: Tiff CNV010_20210606_111_t31 segmented (Tiff n°12), gabor param 0.79, fill param 20, score: 0.8403
# CNV_multiples: Tiff CNV010_20210606_111_t49 segmented (Tiff n°13), gabor param 0.79, fill param 20, score: 0.8421
# CNV_multiples: Tiff CNV010_20210606_137_t7 segmented (Tiff n°14), gabor param 0.79, fill param 20, score: 0.8832
# CNV_multiples: Tiff CNV010_20210606_137_t31 segmented (Tiff n°15), gabor param 0.79, fill param 20, score: 0.7736
# CNV_multiples: Tiff CNV010_20210606_137_t49 segmented (Tiff n°16), gabor param 0.79, fill param 20, score: 0.8853
# CNV_multiples: Tiff CNV010_20210606_156_t7 segmented (Tiff n°17), gabor param 0.79, fill param 20, score: 0.834
# CNV_multiples: Tiff CNV010_20210606_156_t31 segmented (Tiff n°18), gabor param 0.79, fill param 20, score: 0.6583
# CNV_multiples: Tiff CNV010_20210606_156_t49 segmented (Tiff n°19), gabor param 0.79, fill param 20, score: 0.683
# CNV_multiples: Tiff CNV011_20210612_205_t25 segmented (Tiff n°20), gabor param 0.79, fill param 20, score: 0.7433
# CNV_multiples: Tiff CNV011_20210612_205_t49 segmented (Tiff n°21), gabor param 0.79, fill param 20, score: 0.6394
# CNV_multiples: Tiff CNV011_20210612_221_t49 segmented (Tiff n°22), gabor param 0.79, fill param 20, score: 0.7381
# CNV_multiples: Tiff CNV012_20210618_409_t49 segmented (Tiff n°23), gabor param 0.79, fill param 20, score: 0.8268
# CNV_multiples: Tiff CNV012_20210618_410_t1 segmented (Tiff n°24), gabor param 0.79, fill param 20, score: 0.8662
# CNV_multiples: Tiff CNV015_20210717_108_t1 segmented (Tiff n°25), gabor param 0.79, fill param 20, score: 0.8206
# CNV_multiples: Tiff CNV015_20210717_108_t13 segmented (Tiff n°26), gabor param 0.79, fill param 20, score: 0.8948
# CNV_multiples: Tiff CNV015_20210717_108_t22 segmented (Tiff n°27), gabor param 0.79, fill param 20, score: 0.8784
# CNV_multiples: Tiff CNV015_20210717_108_t23 segmented (Tiff n°28), gabor param 0.79, fill param 20, score: 0.892
# CNV_multiples: Tiff CNV015_20210717_108_t24 segmented (Tiff n°29), gabor param 0.79, fill param 20, score: 0.9004
# CNV_multiples: Tiff CNV015_20210717_108_t25 segmented (Tiff n°30), gabor param 0.79, fill param 20, score: 0.8928
# CNV_multiples: Tiff CNV015_20210717_110_25-0004 segmented (Tiff n°31), gabor param 0.79, fill param 20, score: 0.803
# CNV_multiples: Tiff CNV015_20210717_110_25-0005 segmented (Tiff n°32), gabor param 0.79, fill param 20, score: 0.8485
# CNV_multiples: Tiff CNV015_20210717_110_25-0008 segmented (Tiff n°33), gabor param 0.79, fill param 20, score: 0.8446
# CNV_multiples: Tiff CNV015_20210717_110_25-0009 segmented (Tiff n°34), gabor param 0.79, fill param 20, score: 0.8512
# CNV_multiples: Tiff CNV015_20210717_110_25-0010 segmented (Tiff n°35), gabor param 0.79, fill param 20, score: 0.819
# CNV_multiples: Tiff CNV015_20210717_110_25-0011 segmented (Tiff n°36), gabor param 0.79, fill param 20, score: 0.809
# CNV_multiples: Tiff CNV015_20210717_110_25-0013 segmented (Tiff n°37), gabor param 0.79, fill param 20, score: 0.817
# CNV_multiples: Tiff CNV015_20210717_110_25-0014 segmented (Tiff n°38), gabor param 0.79, fill param 20, score: 0.8054
# CNV_multiples: Tiff CNV015_20210717_110_25-0016 segmented (Tiff n°39), gabor param 0.79, fill param 20, score: 0.8395
# CNV_multiples: Tiff CNV015_20210717_110_25-0018 segmented (Tiff n°40), gabor param 0.79, fill param 20, score: 0.8372
# CNV_multiples: Tiff CNV015_20210717_110_25-0019 segmented (Tiff n°41), gabor param 0.79, fill param 20, score: 0.8333
# CNV_multiples: Tiff CNV015_20210717_110_25-0020 segmented (Tiff n°42), gabor param 0.79, fill param 20, score: 0.8242
# CNV_multiples: Tiff CNV015_20210717_110_25-0021 segmented (Tiff n°43), gabor param 0.79, fill param 20, score: 0.8289
# CNV_multiples: Tiff CNV015_20210717_110_25-0022 segmented (Tiff n°44), gabor param 0.79, fill param 20, score: 0.826
# CNV_multiples: Tiff CNV015_20210717_110_25-0023 segmented (Tiff n°45), gabor param 0.79, fill param 20, score: 0.7889
# CNV_multiples: Tiff CNV015_20210717_110_25-0024 segmented (Tiff n°46), gabor param 0.79, fill param 20, score: 0.8327
# CNV_multiples: Tiff CNV015_20210717_118_t1 segmented (Tiff n°47), gabor param 0.79, fill param 20, score: 0.8166
# CNV_multiples: Tiff CNV015_20210717_118_t25 segmented (Tiff n°48), gabor param 0.79, fill param 20, score: 0.7885
# CNV_multiples: Tiff CNV015_20210717_125_t1 segmented (Tiff n°49), gabor param 0.79, fill param 20, score: 0.8827
# CNV_multiples: Tiff CNV015_20210717_125_t13 segmented (Tiff n°50), gabor param 0.79, fill param 20, score: 0.827
# CNV_multiples: Tiff CNV015_20210717_125_t25 segmented (Tiff n°51), gabor param 0.79, fill param 20, score: 0.8432
# CNV_multiples: Tiff CNV016_20210804_434_t49 segmented (Tiff n°52), gabor param 0.79, fill param 20, score: 0.7483
# CNV_multiples: Tiff CNV016_20210804_435_t49 segmented (Tiff n°53), gabor param 0.79, fill param 20, score: 0.6772
# CNV_multiples: Tiff CNV016_20210804_440_t49 segmented (Tiff n°54), gabor param 0.79, fill param 20, score: 0.7169
# CNV_multiples: Tiff CNV016_20210804_441_t49 segmented (Tiff n°55), gabor param 0.79, fill param 20, score: 0.6302
# CNV_multiples: Tiff CNV016_20210804_442_t1 segmented (Tiff n°56), gabor param 0.79, fill param 20, score: 0.7741
# CNV_multiples: Tiff CNV016_20210804_442_t49 segmented (Tiff n°57), gabor param 0.79, fill param 20, score: 0.669
# CNV_multiples: Tiff CNV016_20210804_487_t1 segmented (Tiff n°58), gabor param 0.79, fill param 20, score: 0.7903
# CNV_multiples: Tiff CNV016_20210804_487_t25 segmented (Tiff n°59), gabor param 0.79, fill param 20, score: 0.8709
# CNV_multiples: Tiff CNV016_20210804_487_t49 segmented (Tiff n°60), gabor param 0.79, fill param 20, score: 0.7365
# CNV_multiples: Tiff CNV016_20210804_492_t25 segmented (Tiff n°61), gabor param 0.79, fill param 20, score: 0.8735
# CNV_multiples: Tiff CNV019_20210904_233_t49 segmented (Tiff n°62), gabor param 0.79, fill param 20, score: 0.8115
# CNV_multiples: Tiff CNV022_016_t1 segmented (Tiff n°63), gabor param 0.79, fill param 20, score: 0.8473
# CNV_multiples: Tiff CNV022_016_t25 segmented (Tiff n°64), gabor param 0.79, fill param 20, score: 0.7765
# CNV_multiples: Tiff CNV022_077_t25 segmented (Tiff n°65), gabor param 0.79, fill param 20, score: 0.7512
# CNV_multiples: Tiff CNV022_077_t47 segmented (Tiff n°66), gabor param 0.79, fill param 20, score: 0.6941
# CNV_multiples: Tiff CNV022_077_t48 segmented (Tiff n°67), gabor param 0.79, fill param 20, score: 0.7032
# CNV_multiples: Tiff CNV022_077_t49 segmented (Tiff n°68), gabor param 0.79, fill param 20, score: 0.672
# CNV_multiples: Tiff CNV026_136_t41 segmented (Tiff n°69), gabor param 0.79, fill param 20, score: 0.8022
# CNV_multiples: Tiff CNV026_141_t41 segmented (Tiff n°70), gabor param 0.79, fill param 20, score: 0.5523
# CNV_multiples: Tiff CNV028_38_t41 segmented (Tiff n°71), gabor param 0.79, fill param 20, score: 0.6823
# CNV_multiples: Tiff CNV028_40_t41 segmented (Tiff n°72), gabor param 0.79, fill param 20, score: 0.7206
# CNV_multiples: Tiff CNV028_80_t41 segmented (Tiff n°73), gabor param 0.79, fill param 20, score: 0.7888
# CNV_multiples: Tiff CNV028_82_t41 segmented (Tiff n°74), gabor param 0.79, fill param 20, score: 0.6382
# CNV_multiples: Tiff CNV049_20220610_200-0001 segmented (Tiff n°75), gabor param 0.79, fill param 20, score: 0.8805
# CNV_multiples: Tiff CNV049_20220610_200-0002 segmented (Tiff n°76), gabor param 0.79, fill param 20, score: 0.8927
# CNV_multiples: Tiff CNV049_20220610_200-0003 segmented (Tiff n°77), gabor param 0.79, fill param 20, score: 0.8963
# CNV_multiples: Tiff CNV049_20220610_200-0006 segmented (Tiff n°78), gabor param 0.79, fill param 20, score: 0.8957
# CNV_multiples: Tiff CNV049_20220610_200-0007 segmented (Tiff n°79), gabor param 0.79, fill param 20, score: 0.9211
# CNV_multiples: Tiff CNV049_20220610_200-0008 segmented (Tiff n°80), gabor param 0.79, fill param 20, score: 0.9005
# CNV_multiples: Tiff CNV049_20220610_200-0009 segmented (Tiff n°81), gabor param 0.79, fill param 20, score: 0.9148
# CNV_multiples: Tiff CNV049_20220610_200-0011 segmented (Tiff n°82), gabor param 0.79, fill param 20, score: 0.9094
# CNV_multiples: Tiff CNV049_20220610_200-0012 segmented (Tiff n°83), gabor param 0.79, fill param 20, score: 0.9082
# CNV_multiples: Tiff CNV049_20220610_200-0013 segmented (Tiff n°84), gabor param 0.79, fill param 20, score: 0.9137
# CNV_multiples: Tiff CNV049_20220610_200-0015 segmented (Tiff n°85), gabor param 0.79, fill param 20, score: 0.7814
# CNV_multiples: Tiff CNV049_20220610_200-0016 segmented (Tiff n°86), gabor param 0.79, fill param 20, score: 0.8993
# CNV_multiples: Tiff CNV049_20220610_200-0019 segmented (Tiff n°87), gabor param 0.79, fill param 20, score: 0.8855
# CNV_multiples: Tiff CNV049_20220610_200-0021 segmented (Tiff n°88), gabor param 0.79, fill param 20, score: 0.7682
# CNV_multiples: Tiff CNV049_20220610_200-0023 segmented (Tiff n°89), gabor param 0.79, fill param 20, score: 0.85
# CNV_multiples: Tiff CNV049_20220610_200-0025 segmented (Tiff n°90), gabor param 0.79, fill param 20, score: 0.8198
# CNV_multiples: Tiff CNV049_20220610_200-0026 segmented (Tiff n°91), gabor param 0.79, fill param 20, score: 0.8673
# CNV_multiples: Tiff CNV049_20220610_200-0028 segmented (Tiff n°92), gabor param 0.79, fill param 20, score: 0.8798
# CNV_multiples: Tiff CNV049_20220610_200-0032 segmented (Tiff n°93), gabor param 0.79, fill param 20, score: 0.8656
# CNV_multiples: Tiff CNV049_20220610_200-0033 segmented (Tiff n°94), gabor param 0.79, fill param 20, score: 0.8662
# CNV_multiples: Tiff CNV049_20220610_200-0034 segmented (Tiff n°95), gabor param 0.79, fill param 20, score: 0.8472
# CNV_multiples: Tiff CNV049_20220610_200-0035 segmented (Tiff n°96), gabor param 0.79, fill param 20, score: 0.9009
# CNV_multiples: Tiff CNV049_20220610_200-0036 segmented (Tiff n°97), gabor param 0.79, fill param 20, score: 0.8371
# CNV_multiples: Tiff CNV049_20220610_200-0037 segmented (Tiff n°98), gabor param 0.79, fill param 20, score: 0.8547
# CNV_multiples: Tiff CNV049_20220610_200-0038 segmented (Tiff n°99), gabor param 0.79, fill param 20, score: 0.8647
# CNV_multiples: Tiff CNV049_20220610_200-0039 segmented (Tiff n°100), gabor param 0.79, fill param 20, score: 0.8915
# CNV_multiples: Tiff CNV049_20220610_200-0041 segmented (Tiff n°101), gabor param 0.79, fill param 20, score: 0.8693
# CNV_multiples: Tiff CNV049_20220610_200-0042 segmented (Tiff n°102), gabor param 0.79, fill param 20, score: 0.8452
# CNV_multiples: Tiff CNV049_20220610_200-0043 segmented (Tiff n°103), gabor param 0.79, fill param 20, score: 0.8459
# CNV_multiples: Tiff CNV049_20220610_200-0044 segmented (Tiff n°104), gabor param 0.79, fill param 20, score: 0.8554
# CNV_multiples: Tiff CNV049_20220610_200-0045 segmented (Tiff n°105), gabor param 0.79, fill param 20, score: 0.8731
# CNV_multiples: Tiff CNV049_20220610_200-0047 segmented (Tiff n°106), gabor param 0.79, fill param 20, score: 0.8446
# CNV_multiples: Tiff CNV049_20220610_200-0048 segmented (Tiff n°107), gabor param 0.79, fill param 20, score: 0.8776
# CNV_multiples: Tiff CNV062_096_t48 segmented (Tiff n°108), gabor param 0.79, fill param 20, score: 0.6755
# CNV_multiples: Tiff CNV062_119_t48 segmented (Tiff n°109), gabor param 0.79, fill param 20, score: 0.5269
# CNV_multiples: Tiff CNV062_208_t48 segmented (Tiff n°110), gabor param 0.79, fill param 20, score: 0.8238
# CNV_multiples: Tiff CNV062_211_t19 segmented (Tiff n°111), gabor param 0.79, fill param 20, score: 0.8442
# CNV_multiples: Tiff CNV062_211_t48 segmented (Tiff n°112), gabor param 0.79, fill param 20, score: 0.8426
#     gabor_param  fill_param  Min_pixels  Dice scores
# 0          0.76           5        4000     0.828662
# 1          0.77           5        4000     0.830327
# 2          0.78           5        4000     0.831322
# 3          0.79           5        4000     0.830862
# 4          0.76          10        4000     0.827726
# 5          0.77          10        4000     0.829560
# 6          0.78          10        4000     0.829568
# 7          0.79          10        4000     0.829298
# 8          0.76          15        4000     0.820681
# 9          0.77          15        4000     0.822667
# 10         0.78          15        4000     0.823008
# 11         0.79          15        4000     0.824317
# 12         0.76          20        4000     0.811013
# 13         0.77          20        4000     0.813748
# 14         0.78          20        4000     0.814209
# 15         0.79          20        4000     0.818268

# %% [markdown]
# ## Predict on Test set with best hyperparameters

# %%
file_dir = '/Users/aaronmamann/Desktop/Cleaned_Datasets_Clemence/Validation/test' # change this into your own path
image_files_name = 'Source images'
mask_files_name = 'Masks'
dice_scores = np.array(list(create_masks(file_dir,image_files_name,mask_files_name,gabor_parameter=0.78,fill_cells=5,thresh_small_objects=3700,save_predicted_mask=True,compute_score=True).values()))

print('The mean of all the dice scores on the test set is :')
print(dice_scores.mean())
print ('The standard deviation of all the dice scores on the test set is')
print(dice_scores.std())
# Out:
# /Users/aaronmamann/miniforge3/envs/migrationpytorch/lib/python3.9/site-packages/skimage/util/dtype.py:541: UserWarning: Downcasting uint16 to uint8 without scaling because max value 255 fits in uint8
#   return _convert(image, np.uint8, force_copy)
# /var/folders/z5/z6s0xgdd01xc3rwwp0fs0yxc0000gn/T/ipykernel_12406/2364216888.py:87: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   tiff.imsave("".join([type_dir,'/masks_predicted/',os.path.basename(sequence)]),predicted_mask)
# CNV_mutiples: Tiff CNV010_20210606_066_t24 segmented (Tiff n°1), gabor param 0.78, fill param 5, score: 0.9027
# CNV_mutiples: Tiff CNV010_20210606_072_t1 segmented (Tiff n°2), gabor param 0.78, fill param 5, score: 0.8157
# CNV_mutiples: Tiff CNV010_20210606_072_t25 segmented (Tiff n°3), gabor param 0.78, fill param 5, score: 0.6241
# CNV_mutiples: Tiff CNV010_20210606_095_t7 segmented (Tiff n°4), gabor param 0.78, fill param 5, score: 0.8922
# CNV_mutiples: Tiff CNV011_20210612_205_t25 segmented (Tiff n°5), gabor param 0.78, fill param 5, score: 0.8
# CNV_mutiples: Tiff CNV015_20210717_108_t22 segmented (Tiff n°6), gabor param 0.78, fill param 5, score: 0.8843
# CNV_mutiples: Tiff CNV015_20210717_108_t25 segmented (Tiff n°7), gabor param 0.78, fill param 5, score: 0.8991
# CNV_mutiples: Tiff CNV015_20210717_110_25-0008 segmented (Tiff n°8), gabor param 0.78, fill param 5, score: 0.8572
# CNV_mutiples: Tiff CNV015_20210717_110_25-0011 segmented (Tiff n°9), gabor param 0.78, fill param 5, score: 0.8184
# CNV_mutiples: Tiff CNV015_20210717_110_25-0012 segmented (Tiff n°10), gabor param 0.78, fill param 5, score: 0.8135
# CNV_mutiples: Tiff CNV015_20210717_110_25-0013 segmented (Tiff n°11), gabor param 0.78, fill param 5, score: 0.8279
# CNV_mutiples: Tiff CNV015_20210717_110_25-0019 segmented (Tiff n°12), gabor param 0.78, fill param 5, score: 0.8109
# CNV_mutiples: Tiff CNV015_20210717_110_25-0025 segmented (Tiff n°13), gabor param 0.78, fill param 5, score: 0.7972
# CNV_mutiples: Tiff CNV015_20210717_118_t13 segmented (Tiff n°14), gabor param 0.78, fill param 5, score: 0.8149
# CNV_mutiples: Tiff CNV015_20210717_125_t1 segmented (Tiff n°15), gabor param 0.78, fill param 5, score: 0.8892
# CNV_mutiples: Tiff CNV015_20210717_128_t1 segmented (Tiff n°16), gabor param 0.78, fill param 5, score: 0.7764
# CNV_mutiples: Tiff CNV015_20210717_128_t13 segmented (Tiff n°17), gabor param 0.78, fill param 5, score: 0.8651
# CNV_mutiples: Tiff CNV016_20210804_442_t25 segmented (Tiff n°18), gabor param 0.78, fill param 5, score: 0.7545
# CNV_mutiples: Tiff CNV016_20210804_442_t49 segmented (Tiff n°19), gabor param 0.78, fill param 5, score: 0.7288
# CNV_mutiples: Tiff CNV016_20210804_487_t1 segmented (Tiff n°20), gabor param 0.78, fill param 5, score: 0.8918
# CNV_mutiples: Tiff CNV016_20210804_487_t25 segmented (Tiff n°21), gabor param 0.78, fill param 5, score: 0.8837
# CNV_mutiples: Tiff CNV016_20210804_487_t49 segmented (Tiff n°22), gabor param 0.78, fill param 5, score: 0.767
# CNV_mutiples: Tiff CNV016_20210804_492_t1 segmented (Tiff n°23), gabor param 0.78, fill param 5, score: 0.8915
# CNV_mutiples: Tiff CNV016_20210804_492_t25 segmented (Tiff n°24), gabor param 0.78, fill param 5, score: 0.8811
# CNV_mutiples: Tiff CNV019_20210904_233_t49 segmented (Tiff n°25), gabor param 0.78, fill param 5, score: 0.8306
# CNV_mutiples: Tiff CNV022_016_t1 segmented (Tiff n°26), gabor param 0.78, fill param 5, score: 0.8247
# CNV_mutiples: Tiff CNV022_016_t25 segmented (Tiff n°27), gabor param 0.78, fill param 5, score: 0.7661
# CNV_mutiples: Tiff CNV022_077_t48 segmented (Tiff n°28), gabor param 0.78, fill param 5, score: 0.6872
# CNV_mutiples: Tiff CNV026_119_t41 segmented (Tiff n°29), gabor param 0.78, fill param 5, score: 0.6763
# CNV_mutiples: Tiff CNV026_128_t41 segmented (Tiff n°30), gabor param 0.78, fill param 5, score: 0.7214
# CNV_mutiples: Tiff CNV028_82_t41 segmented (Tiff n°31), gabor param 0.78, fill param 5, score: 0.6396
# CNV_mutiples: Tiff CNV049_20220610_200-0001 segmented (Tiff n°32), gabor param 0.78, fill param 5, score: 0.8991
# CNV_mutiples: Tiff CNV049_20220610_200-0002 segmented (Tiff n°33), gabor param 0.78, fill param 5, score: 0.8992
# CNV_mutiples: Tiff CNV049_20220610_200-0004 segmented (Tiff n°34), gabor param 0.78, fill param 5, score: 0.9046
# CNV_mutiples: Tiff CNV049_20220610_200-0009 segmented (Tiff n°35), gabor param 0.78, fill param 5, score: 0.9183
# CNV_mutiples: Tiff CNV049_20220610_200-0012 segmented (Tiff n°36), gabor param 0.78, fill param 5, score: 0.9075
# CNV_mutiples: Tiff CNV049_20220610_200-0014 segmented (Tiff n°37), gabor param 0.78, fill param 5, score: 0.9115
# CNV_mutiples: Tiff CNV049_20220610_200-0015 segmented (Tiff n°38), gabor param 0.78, fill param 5, score: 0.9292
# CNV_mutiples: Tiff CNV049_20220610_200-0017 segmented (Tiff n°39), gabor param 0.78, fill param 5, score: 0.8988
# CNV_mutiples: Tiff CNV049_20220610_200-0018 segmented (Tiff n°40), gabor param 0.78, fill param 5, score: 0.9049
# CNV_mutiples: Tiff CNV049_20220610_200-0035 segmented (Tiff n°41), gabor param 0.78, fill param 5, score: 0.9139
# CNV_mutiples: Tiff CNV049_20220610_200-0041 segmented (Tiff n°42), gabor param 0.78, fill param 5, score: 0.8777
# CNV_mutiples: Tiff CNV049_20220610_200-0042 segmented (Tiff n°43), gabor param 0.78, fill param 5, score: 0.8665
# CNV_mutiples: Tiff CNV049_20220610_200-0044 segmented (Tiff n°44), gabor param 0.78, fill param 5, score: 0.8693
# CNV_mutiples: Tiff CNV049_20220610_200-0047 segmented (Tiff n°45), gabor param 0.78, fill param 5, score: 0.8648
# CNV_mutiples: Tiff CNV049_20220610_200-0048 segmented (Tiff n°46), gabor param 0.78, fill param 5, score: 0.88
# CNV_mutiples: Tiff CNV062_096_t48 segmented (Tiff n°47), gabor param 0.78, fill param 5, score: 0.7012
# CNV_mutiples: Tiff CNV062_119_t48 segmented (Tiff n°48), gabor param 0.78, fill param 5, score: 0.5848
# The mean of all the dice scores on the test set is :
# 0.8284164493282636
# The standard deviation of all the dice scores on the test set is
# 0.08517784348507236
